# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:00, 1.41MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    one_hot = np.zeros((len(x),10))
    for i in range(len(x)):
        one_hot[i,x[i]] = 1
    return one_hot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,[None] + list(image_shape),'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,[None,n_classes],'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,None,'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    #print('x_shape',x_shape)
    filter_shape = conv_ksize +(x_shape[-1],) + (conv_num_outputs, )
    filter_weights = tf.Variable(tf.truncated_normal(filter_shape,0,0.1))
    filter_bias = tf.Variable(tf.zeros(conv_num_outputs))
    padding = 'SAME'
    conv_layer = tf.nn.conv2d(x_tensor,filter_weights,list((1,) + conv_strides + (1,)), padding)
    conv_layer = tf.nn.bias_add(conv_layer, filter_bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(conv_layer,
                               ksize=[1] + list(pool_ksize) + [1],
                               strides=[1] + list(pool_strides) + [1],
                               padding=padding)
    
    
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy as np
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    #print(x_shape)
    
    #print(tf.reduce_sum(x_shape[1:]))
    #return tf.reshape(x_tensor,[-1,tf.reduce_sum(x_shape[1:])])
    
    #print(np.prod(x_shape[1:]))
    return tf.reshape(x_tensor,[-1,np.prod(x_shape[1:])])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    #print(x_shape[-1])
    weight_shape = list((x_shape[-1],) + (num_outputs,))
    weight = tf.Variable(tf.truncated_normal(weight_shape,0,0.1))
    bias = tf.Variable(tf.zeros(num_outputs))

    return  tf.nn.relu(tf.add(tf.matmul(x_tensor,weight),bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight_shape = list((x_shape[-1], ) + (num_outputs, ))
    weight = tf.Variable(tf.truncated_normal(weight_shape,0,0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    model = conv2d_maxpool(x,conv_num_outputs=16,conv_ksize=(4,4),conv_strides=(1,1), pool_ksize=(8,8),pool_strides=(1,1))
    model = conv2d_maxpool(model,conv_num_outputs=4,conv_ksize=(4,4),conv_strides=(1,1), pool_ksize=(8,8),pool_strides=(1,1))
    model = tf.nn.dropout(model,keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model = flatten(model)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    model = fully_conn(model,384)
    model = tf.nn.dropout(model,keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    model = output(model, 10)
    
    
    # TODO: return output
    return model


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    v_accuracy = session.run(accuracy,feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})
    print('LOSS:{0},VALIDATION ACCURACY:{1}'.format(loss,v_accuracy))

# %% [markdown]
# # Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 128
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Epoch  2, CIFAR-10 Batch 1:  Epoch  6, CIFAR-10 Batch 1:  LOSS:1.8573845624923706,VALIDATION ACCURACY:0.32760000228881836
# Epoch  7, CIFAR-10 Batch 1:  LOSS:1.820723295211792,VALIDATION ACCURACY:0.3515999913215637
# Epoch  8, CIFAR-10 Batch 1:  LOSS:1.762955904006958,VALIDATION ACCURACY:0.36559998989105225
# Epoch  9, CIFAR-10 Batch 1:  LOSS:1.7438057661056519,VALIDATION ACCURACY:0.3806000053882599
# Epoch 10, CIFAR-10 Batch 1:  LOSS:1.6760517358779907,VALIDATION ACCURACY:0.4083999991416931
# Epoch 11, CIFAR-10 Batch 1:  LOSS:1.662649393081665,VALIDATION ACCURACY:0.4146000146865845
# Epoch 12, CIFAR-10 Batch 1:  LOSS:1.6213672161102295,VALIDATION ACCURACY:0.428600013256073
# Epoch 13, CIFAR-10 Batch 1:  LOSS:1.5880489349365234,VALIDATION ACCURACY:0.4246000051498413
# Epoch 14, CIFAR-10 Batch 1:  LOSS:1.5623573064804077,VALIDATION ACCURACY:0.428600013256073
# Epoch 15, CIFAR-10 Batch 1:  LOSS:1.5429188013076782,VALIDATION ACCURACY:0.43220001459121704
# Epoch 16, CIFAR-10 Batch 1:  LOSS:1.5291028022766113,VALIDATION ACCURACY:0.4375999867916107
# Epoch 17, CIFAR-10 Batch 1:  LOSS:1.5267342329025269,VALIDATION ACCURACY:0.43479999899864197
# Epoch 18, CIFAR-10 Batch 1:  LOSS:1.4749784469604492,VALIDATION ACCURACY:0.4465999901294708
# Epoch 19, CIFAR-10 Batch 1:  LOSS:1.4728082418441772,VALIDATION ACCURACY:0.44620001316070557
# Epoch 20, CIFAR-10 Batch 1:  LOSS:1.445778250694275,VALIDATION ACCURACY:0.4431999921798706
# Epoch 21, CIFAR-10 Batch 1:  LOSS:1.4474459886550903,VALIDATION ACCURACY:0.44679999351501465
# Epoch 22, CIFAR-10 Batch 1:  LOSS:1.4164226055145264,VALIDATION ACCURACY:0.44940000772476196
# Epoch 23, CIFAR-10 Batch 1:  LOSS:1.396736741065979,VALIDATION ACCURACY:0.46239998936653137
# Epoch 24, CIFAR-10 Batch 1:  LOSS:1.3809921741485596,VALIDATION ACCURACY:0.4551999866962433
# Epoch 25, CIFAR-10 Batch 1:  LOSS:1.3881652355194092,VALIDATION ACCURACY:0.4535999894142151
# Epoch 26, CIFAR-10 Batch 1:  LOSS:1.3463345766067505,VALIDATION ACCURACY:0.4611999988555908
# Epoch 27, CIFAR-10 Batch 1:  LOSS:1.347622036933899,VALIDATION ACCURACY:0.4666000008583069
# Epoch 28, CIFAR-10 Batch 1:  LOSS:1.3289501667022705,VALIDATION ACCURACY:0.462799996137619
# Epoch 29, CIFAR-10 Batch 1:  LOSS:1.341334342956543,VALIDATION ACCURACY:0.460999995470047
# Epoch 30, CIFAR-10 Batch 1:  LOSS:1.3014088869094849,VALIDATION ACCURACY:0.45899999141693115
# Epoch 31, CIFAR-10 Batch 1:  LOSS:1.282456874847412,VALIDATION ACCURACY:0.48080000281333923
# Epoch 32, CIFAR-10 Batch 1:  LOSS:1.2701098918914795,VALIDATION ACCURACY:0.4652000069618225
# Epoch 33, CIFAR-10 Batch 1:  LOSS:1.2686066627502441,VALIDATION ACCURACY:0.4797999858856201
# Epoch 34, CIFAR-10 Batch 1:  LOSS:1.2412614822387695,VALIDATION ACCURACY:0.47999998927116394
# Epoch 35, CIFAR-10 Batch 1:  LOSS:1.2450140714645386,VALIDATION ACCURACY:0.4726000130176544
# Epoch 36, CIFAR-10 Batch 1:  LOSS:1.2254902124404907,VALIDATION ACCURACY:0.4781999886035919
# Epoch 37, CIFAR-10 Batch 1:  LOSS:1.2076290845870972,VALIDATION ACCURACY:0.49000000953674316
# Epoch 38, CIFAR-10 Batch 1:  LOSS:1.191759705543518,VALIDATION ACCURACY:0.4830000102519989
# Epoch 39, CIFAR-10 Batch 1:  LOSS:1.1842087507247925,VALIDATION ACCURACY:0.49079999327659607
# Epoch 40, CIFAR-10 Batch 1:  LOSS:1.165162205696106,VALIDATION ACCURACY:0.48919999599456787
# Epoch 41, CIFAR-10 Batch 1:  LOSS:1.1450492143630981,VALIDATION ACCURACY:0.4828000068664551
# Epoch 42, CIFAR-10 Batch 1:  LOSS:1.1482263803482056,VALIDATION ACCURACY:0.4903999865055084
# Epoch 43, CIFAR-10 Batch 1:  LOSS:1.130577802658081,VALIDATION ACCURACY:0.4869999885559082
# Epoch 44, CIFAR-10 Batch 1:  LOSS:1.1174968481063843,VALIDATION ACCURACY:0.5012000203132629
# Epoch 45, CIFAR-10 Batch 1:  LOSS:1.1138713359832764,VALIDATION ACCURACY:0.4975999891757965
# Epoch 46, CIFAR-10 Batch 1:  LOSS:1.0972460508346558,VALIDATION ACCURACY:0.49799999594688416
# Epoch 47, CIFAR-10 Batch 1:  LOSS:1.0949004888534546,VALIDATION ACCURACY:0.4973999857902527
# Epoch 48, CIFAR-10 Batch 1:  LOSS:1.0868594646453857,VALIDATION ACCURACY:0.4968000054359436
# Epoch 49, CIFAR-10 Batch 1:  LOSS:1.0673035383224487,VALIDATION ACCURACY:0.49540001153945923
# Epoch 50, CIFAR-10 Batch 1:  LOSS:1.0702235698699951,VALIDATION ACCURACY:0.49000000953674316
# Epoch 51, CIFAR-10 Batch 1:  LOSS:1.0258935689926147,VALIDATION ACCURACY:0.4997999966144562
# Epoch 52, CIFAR-10 Batch 1:  LOSS:1.0493853092193604,VALIDATION ACCURACY:0.5040000081062317
# Epoch 53, CIFAR-10 Batch 1:  LOSS:1.0279669761657715,VALIDATION ACCURACY:0.49219998717308044
# Epoch 54, CIFAR-10 Batch 1:  LOSS:1.0049246549606323,VALIDATION ACCURACY:0.5045999884605408
# Epoch 55, CIFAR-10 Batch 1:  LOSS:1.001481056213379,VALIDATION ACCURACY:0.5077999830245972
# Epoch 56, CIFAR-10 Batch 1:  LOSS:0.9887867569923401,VALIDATION ACCURACY:0.5004000067710876
# Epoch 57, CIFAR-10 Batch 1:  LOSS:0.9733386635780334,VALIDATION ACCURACY:0.504800021648407
# Epoch 58, CIFAR-10 Batch 1:  LOSS:0.9623295664787292,VALIDATION ACCURACY:0.5040000081062317
# Epoch 59, CIFAR-10 Batch 1:  LOSS:0.9680875539779663,VALIDATION ACCURACY:0.5058000087738037
# Epoch 60, CIFAR-10 Batch 1:  LOSS:0.9629873037338257,VALIDATION ACCURACY:0.5105999708175659
# Epoch 61, CIFAR-10 Batch 1:  LOSS:0.9575886130332947,VALIDATION ACCURACY:0.5062000155448914
# Epoch 62, CIFAR-10 Batch 1:  LOSS:0.929822564125061,VALIDATION ACCURACY:0.5112000107765198
# Epoch 63, CIFAR-10 Batch 1:  LOSS:0.920423150062561,VALIDATION ACCURACY:0.5127999782562256
# Epoch 64, CIFAR-10 Batch 1:  LOSS:0.902044951915741,VALIDATION ACCURACY:0.5094000101089478
# Epoch 65, CIFAR-10 Batch 1:  LOSS:0.892157256603241,VALIDATION ACCURACY:0.5138000249862671
# Epoch 66, CIFAR-10 Batch 1:  LOSS:0.8894202709197998,VALIDATION ACCURACY:0.5126000046730042
# Epoch 67, CIFAR-10 Batch 1:  LOSS:0.8983495831489563,VALIDATION ACCURACY:0.5098000168800354
# Epoch 68, CIFAR-10 Batch 1:  LOSS:0.8621292114257812,VALIDATION ACCURACY:0.5174000263214111
# Epoch 69, CIFAR-10 Batch 1:  LOSS:0.8542599678039551,VALIDATION ACCURACY:0.5166000127792358
# Epoch 70, CIFAR-10 Batch 1:  LOSS:0.8294516205787659,VALIDATION ACCURACY:0.5135999917984009
# Epoch 71, CIFAR-10 Batch 1:  LOSS:0.833888828754425,VALIDATION ACCURACY:0.5202000141143799
# Epoch 72, CIFAR-10 Batch 1:  LOSS:0.8135702610015869,VALIDATION ACCURACY:0.5127999782562256
# Epoch 73, CIFAR-10 Batch 1:  LOSS:0.8117650151252747,VALIDATION ACCURACY:0.5149999856948853
# Epoch 74, CIFAR-10 Batch 1:  LOSS:0.8142575621604919,VALIDATION ACCURACY:0.519599974155426
# Epoch 75, CIFAR-10 Batch 1:  LOSS:0.8028984069824219,VALIDATION ACCURACY:0.5203999876976013
# Epoch 76, CIFAR-10 Batch 1:  LOSS:0.7880274057388306,VALIDATION ACCURACY:0.519599974155426
# Epoch 77, CIFAR-10 Batch 1:  LOSS:0.7877634763717651,VALIDATION ACCURACY:0.525600016117096
# Epoch 78, CIFAR-10 Batch 1:  LOSS:0.7666420340538025,VALIDATION ACCURACY:0.5199999809265137
# Epoch 79, CIFAR-10 Batch 1:  LOSS:0.7442396283149719,VALIDATION ACCURACY:0.5267999768257141
# Epoch 80, CIFAR-10 Batch 1:  LOSS:0.7400874495506287,VALIDATION ACCURACY:0.5184000134468079
# Epoch 81, CIFAR-10 Batch 1:  LOSS:0.7374560832977295,VALIDATION ACCURACY:0.5170000195503235
# Epoch 82, CIFAR-10 Batch 1:  LOSS:0.7518662810325623,VALIDATION ACCURACY:0.5217999815940857
# Epoch 83, CIFAR-10 Batch 1:  LOSS:0.7271207571029663,VALIDATION ACCURACY:0.5257999897003174
# Epoch 84, CIFAR-10 Batch 1:  LOSS:0.7125075459480286,VALIDATION ACCURACY:0.5278000235557556
# Epoch 85, CIFAR-10 Batch 1:  LOSS:0.7166793346405029,VALIDATION ACCURACY:0.5157999992370605
# Epoch 86, CIFAR-10 Batch 1:  LOSS:0.7330242991447449,VALIDATION ACCURACY:0.5135999917984009
# Epoch 87, CIFAR-10 Batch 1:  LOSS:0.7051892280578613,VALIDATION ACCURACY:0.5253999829292297
# Epoch 88, CIFAR-10 Batch 1:  LOSS:0.7051636576652527,VALIDATION ACCURACY:0.5235999822616577
# Epoch 89, CIFAR-10 Batch 1:  LOSS:0.6796709299087524,VALIDATION ACCURACY:0.522599995136261
# Epoch 90, CIFAR-10 Batch 1:  LOSS:0.6984251141548157,VALIDATION ACCURACY:0.5094000101089478
# Epoch 91, CIFAR-10 Batch 1:  LOSS:0.6864481568336487,VALIDATION ACCURACY:0.527999997138977
# Epoch 92, CIFAR-10 Batch 1:  LOSS:0.6443030834197998,VALIDATION ACCURACY:0.5288000106811523
# Epoch 93, CIFAR-10 Batch 1:  LOSS:0.6524515748023987,VALIDATION ACCURACY:0.5203999876976013
# Epoch 94, CIFAR-10 Batch 1:  LOSS:0.7600946426391602,VALIDATION ACCURACY:0.49799999594688416
# Epoch 95, CIFAR-10 Batch 1:  LOSS:0.6419135928153992,VALIDATION ACCURACY:0.5235999822616577
# Epoch 96, CIFAR-10 Batch 1:  LOSS:0.6319313645362854,VALIDATION ACCURACY:0.5281999707221985
# Epoch 97, CIFAR-10 Batch 1:  LOSS:0.6151746511459351,VALIDATION ACCURACY:0.5288000106811523
# Epoch 98, CIFAR-10 Batch 1:  LOSS:0.6409439444541931,VALIDATION ACCURACY:0.5217999815940857
# Epoch 99, CIFAR-10 Batch 1:  LOSS:0.5956544876098633,VALIDATION ACCURACY:0.527999997138977
# Epoch 100, CIFAR-10 Batch 1:  LOSS:0.6025963425636292,VALIDATION ACCURACY:0.5231999754905701
# Epoch 101, CIFAR-10 Batch 1:  LOSS:0.586217999458313,VALIDATION ACCURACY:0.517799973487854
# Epoch 102, CIFAR-10 Batch 1:  LOSS:0.5732150077819824,VALIDATION ACCURACY:0.5270000100135803
# Epoch 103, CIFAR-10 Batch 1:  LOSS:0.5642938613891602,VALIDATION ACCURACY:0.5264000296592712
# Epoch 104, CIFAR-10 Batch 1:  LOSS:0.5857418775558472,VALIDATION ACCURACY:0.5303999781608582
# Epoch 105, CIFAR-10 Batch 1:  LOSS:0.5615073442459106,VALIDATION ACCURACY:0.5260000228881836
# Epoch 106, CIFAR-10 Batch 1:  LOSS:0.5736674666404724,VALIDATION ACCURACY:0.5231999754905701
# Epoch 107, CIFAR-10 Batch 1:  LOSS:0.5688005089759827,VALIDATION ACCURACY:0.5188000202178955
# Epoch 108, CIFAR-10 Batch 1:  LOSS:0.5533962845802307,VALIDATION ACCURACY:0.5156000256538391
# Epoch 109, CIFAR-10 Batch 1:  LOSS:0.5307914018630981,VALIDATION ACCURACY:0.5228000283241272
# Epoch 110, CIFAR-10 Batch 1:  LOSS:0.5230416059494019,VALIDATION ACCURACY:0.5224000215530396
# Epoch 111, CIFAR-10 Batch 1:  LOSS:0.5337076187133789,VALIDATION ACCURACY:0.5203999876976013
# Epoch 112, CIFAR-10 Batch 1:  LOSS:0.5728006362915039,VALIDATION ACCURACY:0.5
# Epoch 113, CIFAR-10 Batch 1:  LOSS:0.5487569570541382,VALIDATION ACCURACY:0.5192000269889832
# Epoch 114, CIFAR-10 Batch 1:  LOSS:0.5482912659645081,VALIDATION ACCURACY:0.5085999965667725
# Epoch 115, CIFAR-10 Batch 1:  LOSS:0.5830095410346985,VALIDATION ACCURACY:0.5185999870300293
# Epoch 116, CIFAR-10 Batch 1:  LOSS:0.5200745463371277,VALIDATION ACCURACY:0.5199999809265137
# Epoch 117, CIFAR-10 Batch 1:  LOSS:0.5124697685241699,VALIDATION ACCURACY:0.5315999984741211
# Epoch 118, CIFAR-10 Batch 1:  LOSS:0.4882700741291046,VALIDATION ACCURACY:0.5230000019073486
# Epoch 119, CIFAR-10 Batch 1:  LOSS:0.5142191052436829,VALIDATION ACCURACY:0.5175999999046326
# Epoch 120, CIFAR-10 Batch 1:  LOSS:0.4812941253185272,VALIDATION ACCURACY:0.5206000208854675
# Epoch 121, CIFAR-10 Batch 1:  LOSS:0.4925597906112671,VALIDATION ACCURACY:0.5302000045776367
# Epoch 122, CIFAR-10 Batch 1:  LOSS:0.48264724016189575,VALIDATION ACCURACY:0.527400016784668
# Epoch 123, CIFAR-10 Batch 1:  LOSS:0.47472870349884033,VALIDATION ACCURACY:0.5275999903678894
# Epoch 124, CIFAR-10 Batch 1:  LOSS:0.4708836078643799,VALIDATION ACCURACY:0.5288000106811523
# Epoch 125, CIFAR-10 Batch 1:  LOSS:0.46258121728897095,VALIDATION ACCURACY:0.5264000296592712
# Epoch 126, CIFAR-10 Batch 1:  LOSS:0.47084933519363403,VALIDATION ACCURACY:0.5239999890327454
# Epoch 127, CIFAR-10 Batch 1:  LOSS:0.4572044610977173,VALIDATION ACCURACY:0.522599995136261
# Epoch 128, CIFAR-10 Batch 1:  LOSS:0.4512324929237366,VALIDATION ACCURACY:0.525600016117096

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  LOSS:2.302232503890991,VALIDATION ACCURACY:0.09040000289678574
# Epoch  1, CIFAR-10 Batch 2:  LOSS:2.302985906600952,VALIDATION ACCURACY:0.10559999942779541
# Epoch  1, CIFAR-10 Batch 3:  LOSS:2.302131414413452,VALIDATION ACCURACY:0.10679999738931656
# Epoch  1, CIFAR-10 Batch 4:  LOSS:2.302774429321289,VALIDATION ACCURACY:0.09260000288486481
# Epoch  1, CIFAR-10 Batch 5:  LOSS:2.302729845046997,VALIDATION ACCURACY:0.09239999949932098
# Epoch  2, CIFAR-10 Batch 1:  LOSS:2.3026084899902344,VALIDATION ACCURACY:0.09239999949932098
# Epoch  2, CIFAR-10 Batch 2:  LOSS:2.3027431964874268,VALIDATION ACCURACY:0.09880000352859497
# Epoch  2, CIFAR-10 Batch 3:  LOSS:2.301957607269287,VALIDATION ACCURACY:0.10040000081062317
# Epoch  2, CIFAR-10 Batch 4:  LOSS:2.3023598194122314,VALIDATION ACCURACY:0.0934000015258789
# Epoch  2, CIFAR-10 Batch 5:  LOSS:2.301914930343628,VALIDATION ACCURACY:0.09359999746084213
# Epoch  3, CIFAR-10 Batch 1:  LOSS:2.2979259490966797,VALIDATION ACCURACY:0.09279999881982803
# Epoch  3, CIFAR-10 Batch 2:  LOSS:2.292428970336914,VALIDATION ACCURACY:0.12800000607967377
# Epoch  3, CIFAR-10 Batch 3:  LOSS:2.25930118560791,VALIDATION ACCURACY:0.133200004696846
# Epoch  3, CIFAR-10 Batch 4:  LOSS:2.2268500328063965,VALIDATION ACCURACY:0.17219999432563782
# Epoch  3, CIFAR-10 Batch 5:  LOSS:2.2178115844726562,VALIDATION ACCURACY:0.16500000655651093
# Epoch  4, CIFAR-10 Batch 1:  LOSS:2.2482407093048096,VALIDATION ACCURACY:0.1687999963760376
# Epoch  4, CIFAR-10 Batch 2:  LOSS:2.228059768676758,VALIDATION ACCURACY:0.1777999997138977
# Epoch  4, CIFAR-10 Batch 3:  LOSS:2.1945948600769043,VALIDATION ACCURACY:0.19140000641345978
# Epoch  4, CIFAR-10 Batch 4:  LOSS:2.1516919136047363,VALIDATION ACCURACY:0.18479999899864197
# Epoch  4, CIFAR-10 Batch 5:  LOSS:2.155418872833252,VALIDATION ACCURACY:0.19519999623298645
# Epoch  5, CIFAR-10 Batch 1:  LOSS:2.1720986366271973,VALIDATION ACCURACY:0.19380000233650208
# Epoch  5, CIFAR-10 Batch 2:  LOSS:2.154419422149658,VALIDATION ACCURACY:0.1899999976158142
# Epoch  5, CIFAR-10 Batch 3:  LOSS:2.0817975997924805,VALIDATION ACCURACY:0.19939999282360077
# Epoch  5, CIFAR-10 Batch 4:  LOSS:2.04213809967041,VALIDATION ACCURACY:0.20020000636577606
# Epoch  5, CIFAR-10 Batch 5:  LOSS:2.094754695892334,VALIDATION ACCURACY:0.2054000049829483
# Epoch  6, CIFAR-10 Batch 1:  LOSS:2.0477707386016846,VALIDATION ACCURACY:0.2215999960899353
# Epoch  6, CIFAR-10 Batch 2:  LOSS:2.0290017127990723,VALIDATION ACCURACY:0.2508000135421753
# Epoch  6, CIFAR-10 Batch 3:  LOSS:1.9467002153396606,VALIDATION ACCURACY:0.27880001068115234
# Epoch  6, CIFAR-10 Batch 4:  LOSS:1.8405464887619019,VALIDATION ACCURACY:0.298799991607666
# Epoch  6, CIFAR-10 Batch 5:  LOSS:1.8528392314910889,VALIDATION ACCURACY:0.30000001192092896
# Epoch  7, CIFAR-10 Batch 1:  LOSS:1.906734824180603,VALIDATION ACCURACY:0.30979999899864197
# Epoch  7, CIFAR-10 Batch 2:  LOSS:1.9040027856826782,VALIDATION ACCURACY:0.3041999936103821
# Epoch  7, CIFAR-10 Batch 3:  LOSS:1.7902883291244507,VALIDATION ACCURACY:0.3255999982357025
# Epoch  7, CIFAR-10 Batch 4:  LOSS:1.7052077054977417,VALIDATION ACCURACY:0.3343999981880188
# Epoch  7, CIFAR-10 Batch 5:  LOSS:1.7127052545547485,VALIDATION ACCURACY:0.3441999852657318
# Epoch  8, CIFAR-10 Batch 1:  LOSS:1.8197652101516724,VALIDATION ACCURACY:0.3547999858856201
# Epoch  8, CIFAR-10 Batch 2:  LOSS:1.6662495136260986,VALIDATION ACCURACY:0.3758000135421753
# Epoch  8, CIFAR-10 Batch 3:  LOSS:1.5965453386306763,VALIDATION ACCURACY:0.3912000060081482
# Epoch  8, CIFAR-10 Batch 4:  LOSS:1.550364375114441,VALIDATION ACCURACY:0.3917999863624573
# Epoch  8, CIFAR-10 Batch 5:  LOSS:1.5763472318649292,VALIDATION ACCURACY:0.4002000093460083
# Epoch  9, CIFAR-10 Batch 1:  LOSS:1.7066712379455566,VALIDATION ACCURACY:0.41100001335144043
# Epoch  9, CIFAR-10 Batch 2:  LOSS:1.5428440570831299,VALIDATION ACCURACY:0.42640000581741333
# Epoch  9, CIFAR-10 Batch 3:  LOSS:1.453770637512207,VALIDATION ACCURACY:0.4368000030517578
# Epoch  9, CIFAR-10 Batch 4:  LOSS:1.4307349920272827,VALIDATION ACCURACY:0.42899999022483826
# Epoch  9, CIFAR-10 Batch 5:  LOSS:1.480628252029419,VALIDATION ACCURACY:0.44119998812675476
# Epoch 10, CIFAR-10 Batch 1:  LOSS:1.6415120363235474,VALIDATION ACCURACY:0.45179998874664307
# Epoch 10, CIFAR-10 Batch 2:  LOSS:1.4869089126586914,VALIDATION ACCURACY:0.4544000029563904
# Epoch 10, CIFAR-10 Batch 3:  LOSS:1.4039024114608765,VALIDATION ACCURACY:0.44859999418258667
# Epoch 10, CIFAR-10 Batch 4:  LOSS:1.3865245580673218,VALIDATION ACCURACY:0.4490000009536743
# Epoch 10, CIFAR-10 Batch 5:  LOSS:1.4442119598388672,VALIDATION ACCURACY:0.46320000290870667
# Epoch 11, CIFAR-10 Batch 1:  LOSS:1.5871707201004028,VALIDATION ACCURACY:0.4731999933719635
# Epoch 11, CIFAR-10 Batch 2:  LOSS:1.4379688501358032,VALIDATION ACCURACY:0.4742000102996826
# Epoch 11, CIFAR-10 Batch 3:  LOSS:1.3414455652236938,VALIDATION ACCURACY:0.46239998936653137
# Epoch 11, CIFAR-10 Batch 4:  LOSS:1.3403351306915283,VALIDATION ACCURACY:0.46779999136924744
# Epoch 11, CIFAR-10 Batch 5:  LOSS:1.3983131647109985,VALIDATION ACCURACY:0.48179998993873596
# Epoch 12, CIFAR-10 Batch 1:  LOSS:1.5550094842910767,VALIDATION ACCURACY:0.4832000136375427
# Epoch 12, CIFAR-10 Batch 2:  LOSS:1.3990131616592407,VALIDATION ACCURACY:0.47780001163482666
# Epoch 12, CIFAR-10 Batch 3:  LOSS:1.300052523612976,VALIDATION ACCURACY:0.4812000095844269
# Epoch 12, CIFAR-10 Batch 4:  LOSS:1.3172755241394043,VALIDATION ACCURACY:0.4747999906539917
# Epoch 12, CIFAR-10 Batch 5:  LOSS:1.3865666389465332,VALIDATION ACCURACY:0.4878000020980835
# Epoch 13, CIFAR-10 Batch 1:  LOSS:1.5197116136550903,VALIDATION ACCURACY:0.4869999885559082
# Epoch 13, CIFAR-10 Batch 2:  LOSS:1.3553884029388428,VALIDATION ACCURACY:0.4973999857902527
# Epoch 13, CIFAR-10 Batch 3:  LOSS:1.2790675163269043,VALIDATION ACCURACY:0.48240000009536743
# Epoch 13, CIFAR-10 Batch 4:  LOSS:1.2671198844909668,VALIDATION ACCURACY:0.49480000138282776
# Epoch 13, CIFAR-10 Batch 5:  LOSS:1.3486847877502441,VALIDATION ACCURACY:0.49559998512268066
# Epoch 14, CIFAR-10 Batch 1:  LOSS:1.4957046508789062,VALIDATION ACCURACY:0.4986000061035156
# Epoch 14, CIFAR-10 Batch 2:  LOSS:1.329882025718689,VALIDATION ACCURACY:0.5120000243186951
# Epoch 14, CIFAR-10 Batch 3:  LOSS:1.2283955812454224,VALIDATION ACCURACY:0.4934000074863434
# Epoch 14, CIFAR-10 Batch 4:  LOSS:1.251336693763733,VALIDATION ACCURACY:0.4909999966621399
# Epoch 14, CIFAR-10 Batch 5:  LOSS:1.3273884057998657,VALIDATION ACCURACY:0.503000020980835
# Epoch 15, CIFAR-10 Batch 1:  LOSS:1.436245322227478,VALIDATION ACCURACY:0.5059999823570251
# Epoch 15, CIFAR-10 Batch 2:  LOSS:1.3116339445114136,VALIDATION ACCURACY:0.5098000168800354
# Epoch 15, CIFAR-10 Batch 3:  LOSS:1.2424907684326172,VALIDATION ACCURACY:0.5019999742507935
# Epoch 15, CIFAR-10 Batch 4:  LOSS:1.1976070404052734,VALIDATION ACCURACY:0.5203999876976013
# Epoch 15, CIFAR-10 Batch 5:  LOSS:1.3030598163604736,VALIDATION ACCURACY:0.5077999830245972
# Epoch 16, CIFAR-10 Batch 1:  LOSS:1.4009768962860107,VALIDATION ACCURACY:0.5188000202178955
# Epoch 16, CIFAR-10 Batch 2:  LOSS:1.2684541940689087,VALIDATION ACCURACY:0.5145999789237976
# Epoch 16, CIFAR-10 Batch 3:  LOSS:1.1608152389526367,VALIDATION ACCURACY:0.5181999802589417
# Epoch 16, CIFAR-10 Batch 4:  LOSS:1.1755237579345703,VALIDATION ACCURACY:0.522599995136261
# Epoch 16, CIFAR-10 Batch 5:  LOSS:1.2555736303329468,VALIDATION ACCURACY:0.5085999965667725
# Epoch 17, CIFAR-10 Batch 1:  LOSS:1.3795156478881836,VALIDATION ACCURACY:0.5239999890327454
# Epoch 17, CIFAR-10 Batch 2:  LOSS:1.265516757965088,VALIDATION ACCURACY:0.5194000005722046
# Epoch 17, CIFAR-10 Batch 3:  LOSS:1.1377588510513306,VALIDATION ACCURACY:0.5278000235557556
# Epoch 17, CIFAR-10 Batch 4:  LOSS:1.164986491203308,VALIDATION ACCURACY:0.5302000045776367
# Epoch 17, CIFAR-10 Batch 5:  LOSS:1.2332582473754883,VALIDATION ACCURACY:0.5138000249862671
# Epoch 18, CIFAR-10 Batch 1:  LOSS:1.367166519165039,VALIDATION ACCURACY:0.5325999855995178
# Epoch 18, CIFAR-10 Batch 2:  LOSS:1.2165402173995972,VALIDATION ACCURACY:0.5267999768257141
# Epoch 18, CIFAR-10 Batch 3:  LOSS:1.132831335067749,VALIDATION ACCURACY:0.5188000202178955
# Epoch 18, CIFAR-10 Batch 4:  LOSS:1.1825532913208008,VALIDATION ACCURACY:0.5246000289916992
# Epoch 18, CIFAR-10 Batch 5:  LOSS:1.249361276626587,VALIDATION ACCURACY:0.5221999883651733
# Epoch 19, CIFAR-10 Batch 1:  LOSS:1.377785325050354,VALIDATION ACCURACY:0.5058000087738037
# Epoch 19, CIFAR-10 Batch 2:  LOSS:1.2231394052505493,VALIDATION ACCURACY:0.5248000025749207
# Epoch 19, CIFAR-10 Batch 3:  LOSS:1.1052590608596802,VALIDATION ACCURACY:0.5303999781608582
# Epoch 19, CIFAR-10 Batch 4:  LOSS:1.1514536142349243,VALIDATION ACCURACY:0.5335999727249146
# Epoch 19, CIFAR-10 Batch 5:  LOSS:1.20010244846344,VALIDATION ACCURACY:0.531000018119812
# Epoch 20, CIFAR-10 Batch 1:  LOSS:1.327351689338684,VALIDATION ACCURACY:0.5360000133514404
# Epoch 20, CIFAR-10 Batch 2:  LOSS:1.1943943500518799,VALIDATION ACCURACY:0.532800018787384
# Epoch 20, CIFAR-10 Batch 3:  LOSS:1.068833351135254,VALIDATION ACCURACY:0.5424000024795532
# Epoch 20, CIFAR-10 Batch 4:  LOSS:1.1314051151275635,VALIDATION ACCURACY:0.5378000140190125
# Epoch 20, CIFAR-10 Batch 5:  LOSS:1.181543231010437,VALIDATION ACCURACY:0.5371999740600586
# Epoch 21, CIFAR-10 Batch 1:  LOSS:1.2933673858642578,VALIDATION ACCURACY:0.5356000065803528
# Epoch 21, CIFAR-10 Batch 2:  LOSS:1.198721170425415,VALIDATION ACCURACY:0.5314000248908997
# Epoch 21, CIFAR-10 Batch 3:  LOSS:1.0873134136199951,VALIDATION ACCURACY:0.5374000072479248
# Epoch 21, CIFAR-10 Batch 4:  LOSS:1.1266188621520996,VALIDATION ACCURACY:0.5388000011444092
# Epoch 21, CIFAR-10 Batch 5:  LOSS:1.1679071187973022,VALIDATION ACCURACY:0.5514000058174133
# Epoch 22, CIFAR-10 Batch 1:  LOSS:1.2662328481674194,VALIDATION ACCURACY:0.5515999794006348
# Epoch 22, CIFAR-10 Batch 2:  LOSS:1.157538652420044,VALIDATION ACCURACY:0.5365999937057495
# Epoch 22, CIFAR-10 Batch 3:  LOSS:1.0450130701065063,VALIDATION ACCURACY:0.5424000024795532
# Epoch 22, CIFAR-10 Batch 4:  LOSS:1.0997110605239868,VALIDATION ACCURACY:0.5573999881744385
# Epoch 22, CIFAR-10 Batch 5:  LOSS:1.1333271265029907,VALIDATION ACCURACY:0.5465999841690063
# Epoch 23, CIFAR-10 Batch 1:  LOSS:1.22148597240448,VALIDATION ACCURACY:0.5527999997138977
# Epoch 23, CIFAR-10 Batch 2:  LOSS:1.1413319110870361,VALIDATION ACCURACY:0.5473999977111816
# Epoch 23, CIFAR-10 Batch 3:  LOSS:1.0312048196792603,VALIDATION ACCURACY:0.5497999787330627
# Epoch 23, CIFAR-10 Batch 4:  LOSS:1.0884151458740234,VALIDATION ACCURACY:0.553600013256073
# Epoch 23, CIFAR-10 Batch 5:  LOSS:1.1189281940460205,VALIDATION ACCURACY:0.5569999814033508
# Epoch 24, CIFAR-10 Batch 1:  LOSS:1.218526840209961,VALIDATION ACCURACY:0.5576000213623047
# Epoch 24, CIFAR-10 Batch 2:  LOSS:1.1280241012573242,VALIDATION ACCURACY:0.550000011920929
# Epoch 24, CIFAR-10 Batch 3:  LOSS:0.9972044229507446,VALIDATION ACCURACY:0.5568000078201294
# Epoch 24, CIFAR-10 Batch 4:  LOSS:1.0544759035110474,VALIDATION ACCURACY:0.5604000091552734
# Epoch 24, CIFAR-10 Batch 5:  LOSS:1.0952914953231812,VALIDATION ACCURACY:0.5636000037193298
# Epoch 25, CIFAR-10 Batch 1:  LOSS:1.1929261684417725,VALIDATION ACCURACY:0.5608000159263611
# Epoch 25, CIFAR-10 Batch 2:  LOSS:1.1013989448547363,VALIDATION ACCURACY:0.555400013923645
# Epoch 25, CIFAR-10 Batch 3:  LOSS:0.9775856733322144,VALIDATION ACCURACY:0.5590000152587891
# Epoch 25, CIFAR-10 Batch 4:  LOSS:1.0305744409561157,VALIDATION ACCURACY:0.5687999725341797
# Epoch 25, CIFAR-10 Batch 5:  LOSS:1.082061767578125,VALIDATION ACCURACY:0.5576000213623047
# Epoch 26, CIFAR-10 Batch 1:  LOSS:1.1824151277542114,VALIDATION ACCURACY:0.5669999718666077
# Epoch 26, CIFAR-10 Batch 2:  LOSS:1.0921205282211304,VALIDATION ACCURACY:0.5655999779701233
# Epoch 26, CIFAR-10 Batch 3:  LOSS:1.0075633525848389,VALIDATION ACCURACY:0.5573999881744385
# Epoch 26, CIFAR-10 Batch 4:  LOSS:1.0235230922698975,VALIDATION ACCURACY:0.569599986076355
# Epoch 26, CIFAR-10 Batch 5:  LOSS:1.0961182117462158,VALIDATION ACCURACY:0.5527999997138977
# Epoch 27, CIFAR-10 Batch 1:  LOSS:1.1609876155853271,VALIDATION ACCURACY:0.5676000118255615
# Epoch 27, CIFAR-10 Batch 2:  LOSS:1.0963962078094482,VALIDATION ACCURACY:0.5583999752998352
# Epoch 27, CIFAR-10 Batch 3:  LOSS:0.9640578031539917,VALIDATION ACCURACY:0.5659999847412109
# Epoch 27, CIFAR-10 Batch 4:  LOSS:1.0315030813217163,VALIDATION ACCURACY:0.5573999881744385
# Epoch 27, CIFAR-10 Batch 5:  LOSS:1.0395909547805786,VALIDATION ACCURACY:0.5666000247001648
# Epoch 28, CIFAR-10 Batch 1:  LOSS:1.1395699977874756,VALIDATION ACCURACY:0.574400007724762
# Epoch 28, CIFAR-10 Batch 2:  LOSS:1.0790472030639648,VALIDATION ACCURACY:0.5663999915122986
# Epoch 28, CIFAR-10 Batch 3:  LOSS:0.9593043923377991,VALIDATION ACCURACY:0.5712000131607056
# Epoch 28, CIFAR-10 Batch 4:  LOSS:1.0004249811172485,VALIDATION ACCURACY:0.5676000118255615
# Epoch 28, CIFAR-10 Batch 5:  LOSS:1.0403178930282593,VALIDATION ACCURACY:0.5709999799728394
# Epoch 29, CIFAR-10 Batch 1:  LOSS:1.1301023960113525,VALIDATION ACCURACY:0.5738000273704529
# Epoch 29, CIFAR-10 Batch 2:  LOSS:1.0522534847259521,VALIDATION ACCURACY:0.5756000280380249
# Epoch 29, CIFAR-10 Batch 3:  LOSS:0.9583559036254883,VALIDATION ACCURACY:0.5702000260353088
# Epoch 29, CIFAR-10 Batch 4:  LOSS:1.0013587474822998,VALIDATION ACCURACY:0.5709999799728394
# Epoch 29, CIFAR-10 Batch 5:  LOSS:1.019208550453186,VALIDATION ACCURACY:0.5753999948501587
# Epoch 30, CIFAR-10 Batch 1:  LOSS:1.1123249530792236,VALIDATION ACCURACY:0.5776000022888184
# Epoch 30, CIFAR-10 Batch 2:  LOSS:1.033111333847046,VALIDATION ACCURACY:0.5834000110626221
# Epoch 30, CIFAR-10 Batch 3:  LOSS:0.9252879023551941,VALIDATION ACCURACY:0.5827999711036682
# Epoch 30, CIFAR-10 Batch 4:  LOSS:0.9713150262832642,VALIDATION ACCURACY:0.5817999839782715
# Epoch 30, CIFAR-10 Batch 5:  LOSS:1.0143036842346191,VALIDATION ACCURACY:0.5766000151634216
# Epoch 31, CIFAR-10 Batch 1:  LOSS:1.1026976108551025,VALIDATION ACCURACY:0.5813999772071838
# Epoch 31, CIFAR-10 Batch 2:  LOSS:1.045563817024231,VALIDATION ACCURACY:0.5753999948501587
# Epoch 31, CIFAR-10 Batch 3:  LOSS:0.9227580428123474,VALIDATION ACCURACY:0.5812000036239624
# Epoch 31, CIFAR-10 Batch 4:  LOSS:0.9671480059623718,VALIDATION ACCURACY:0.5830000042915344
# Epoch 31, CIFAR-10 Batch 5:  LOSS:1.0026260614395142,VALIDATION ACCURACY:0.5759999752044678
# Epoch 32, CIFAR-10 Batch 1:  LOSS:1.092315673828125,VALIDATION ACCURACY:0.5763999819755554
# Epoch 32, CIFAR-10 Batch 2:  LOSS:1.0100491046905518,VALIDATION ACCURACY:0.5794000029563904
# Epoch 32, CIFAR-10 Batch 3:  LOSS:0.9100043773651123,VALIDATION ACCURACY:0.5831999778747559
# Epoch 32, CIFAR-10 Batch 4:  LOSS:0.9619359374046326,VALIDATION ACCURACY:0.58160001039505
# Epoch 32, CIFAR-10 Batch 5:  LOSS:0.9863983392715454,VALIDATION ACCURACY:0.5812000036239624
# Epoch 33, CIFAR-10 Batch 1:  LOSS:1.0608662366867065,VALIDATION ACCURACY:0.5889999866485596
# Epoch 33, CIFAR-10 Batch 2:  LOSS:1.006509780883789,VALIDATION ACCURACY:0.5803999900817871
# Epoch 33, CIFAR-10 Batch 3:  LOSS:0.9088544845581055,VALIDATION ACCURACY:0.5799999833106995
# Epoch 33, CIFAR-10 Batch 4:  LOSS:0.9556342363357544,VALIDATION ACCURACY:0.5867999792098999
# Epoch 33, CIFAR-10 Batch 5:  LOSS:0.9849665760993958,VALIDATION ACCURACY:0.5734000205993652
# Epoch 34, CIFAR-10 Batch 1:  LOSS:1.084983229637146,VALIDATION ACCURACY:0.5672000050544739
# Epoch 34, CIFAR-10 Batch 2:  LOSS:1.0425347089767456,VALIDATION ACCURACY:0.5655999779701233
# Epoch 34, CIFAR-10 Batch 3:  LOSS:0.9411489367485046,VALIDATION ACCURACY:0.5685999989509583
# Epoch 34, CIFAR-10 Batch 4:  LOSS:0.9427976012229919,VALIDATION ACCURACY:0.5888000130653381
# Epoch 34, CIFAR-10 Batch 5:  LOSS:0.9693517088890076,VALIDATION ACCURACY:0.5812000036239624
# Epoch 35, CIFAR-10 Batch 1:  LOSS:1.064499855041504,VALIDATION ACCURACY:0.579200029373169
# Epoch 35, CIFAR-10 Batch 2:  LOSS:1.0253503322601318,VALIDATION ACCURACY:0.5820000171661377
# Epoch 35, CIFAR-10 Batch 3:  LOSS:0.9311904907226562,VALIDATION ACCURACY:0.5770000219345093
# Epoch 35, CIFAR-10 Batch 4:  LOSS:0.9292423129081726,VALIDATION ACCURACY:0.5935999751091003
# Epoch 35, CIFAR-10 Batch 5:  LOSS:0.9944442510604858,VALIDATION ACCURACY:0.5770000219345093
# Epoch 36, CIFAR-10 Batch 1:  LOSS:1.067525029182434,VALIDATION ACCURACY:0.58160001039505
# Epoch 36, CIFAR-10 Batch 2:  LOSS:1.031638503074646,VALIDATION ACCURACY:0.5722000002861023
# Epoch 36, CIFAR-10 Batch 3:  LOSS:0.9011144042015076,VALIDATION ACCURACY:0.5960000157356262
# Epoch 36, CIFAR-10 Batch 4:  LOSS:0.9378373622894287,VALIDATION ACCURACY:0.5885999798774719
# Epoch 36, CIFAR-10 Batch 5:  LOSS:0.9496206045150757,VALIDATION ACCURACY:0.5910000205039978
# Epoch 37, CIFAR-10 Batch 1:  LOSS:1.0331289768218994,VALIDATION ACCURACY:0.5748000144958496
# Epoch 37, CIFAR-10 Batch 2:  LOSS:1.027312159538269,VALIDATION ACCURACY:0.5767999887466431
# Epoch 37, CIFAR-10 Batch 3:  LOSS:0.8917964100837708,VALIDATION ACCURACY:0.5928000211715698
# Epoch 37, CIFAR-10 Batch 4:  LOSS:0.9256237149238586,VALIDATION ACCURACY:0.5932000279426575
# Epoch 37, CIFAR-10 Batch 5:  LOSS:0.9595212340354919,VALIDATION ACCURACY:0.5857999920845032
# Epoch 38, CIFAR-10 Batch 1:  LOSS:1.0258671045303345,VALIDATION ACCURACY:0.5758000016212463
# Epoch 38, CIFAR-10 Batch 2:  LOSS:1.0346258878707886,VALIDATION ACCURACY:0.5726000070571899
# Epoch 38, CIFAR-10 Batch 3:  LOSS:0.8829172253608704,VALIDATION ACCURACY:0.5857999920845032
# Epoch 38, CIFAR-10 Batch 4:  LOSS:0.9122177362442017,VALIDATION ACCURACY:0.5961999893188477
# Epoch 38, CIFAR-10 Batch 5:  LOSS:0.9383194446563721,VALIDATION ACCURACY:0.5953999757766724
# Epoch 39, CIFAR-10 Batch 1:  LOSS:1.0196080207824707,VALIDATION ACCURACY:0.590399980545044
# Epoch 39, CIFAR-10 Batch 2:  LOSS:0.9859288930892944,VALIDATION ACCURACY:0.5803999900817871
# Epoch 39, CIFAR-10 Batch 3:  LOSS:0.924710750579834,VALIDATION ACCURACY:0.5889999866485596
# Epoch 39, CIFAR-10 Batch 4:  LOSS:0.8825943470001221,VALIDATION ACCURACY:0.5985999703407288
# Epoch 39, CIFAR-10 Batch 5:  LOSS:0.933294951915741,VALIDATION ACCURACY:0.5920000076293945
# Epoch 40, CIFAR-10 Batch 1:  LOSS:1.057358980178833,VALIDATION ACCURACY:0.5694000124931335
# Epoch 40, CIFAR-10 Batch 2:  LOSS:1.0079360008239746,VALIDATION ACCURACY:0.5727999806404114
# Epoch 40, CIFAR-10 Batch 3:  LOSS:0.919242262840271,VALIDATION ACCURACY:0.590399980545044
# Epoch 40, CIFAR-10 Batch 4:  LOSS:0.8829243779182434,VALIDATION ACCURACY:0.5938000082969666
# Epoch 40, CIFAR-10 Batch 5:  LOSS:0.9169608354568481,VALIDATION ACCURACY:0.5947999954223633
# Epoch 41, CIFAR-10 Batch 1:  LOSS:1.0003656148910522,VALIDATION ACCURACY:0.5830000042915344
# Epoch 41, CIFAR-10 Batch 2:  LOSS:1.0305266380310059,VALIDATION ACCURACY:0.5699999928474426
# Epoch 41, CIFAR-10 Batch 3:  LOSS:0.8817433714866638,VALIDATION ACCURACY:0.5938000082969666
# Epoch 41, CIFAR-10 Batch 4:  LOSS:0.8673710227012634,VALIDATION ACCURACY:0.6011999845504761
# Epoch 41, CIFAR-10 Batch 5:  LOSS:0.9226387739181519,VALIDATION ACCURACY:0.5971999764442444
# Epoch 42, CIFAR-10 Batch 1:  LOSS:1.0004286766052246,VALIDATION ACCURACY:0.5848000049591064
# Epoch 42, CIFAR-10 Batch 2:  LOSS:0.9679514169692993,VALIDATION ACCURACY:0.5899999737739563
# Epoch 42, CIFAR-10 Batch 3:  LOSS:0.8458237648010254,VALIDATION ACCURACY:0.6014000177383423
# Epoch 42, CIFAR-10 Batch 4:  LOSS:0.9022551774978638,VALIDATION ACCURACY:0.597000002861023
# Epoch 42, CIFAR-10 Batch 5:  LOSS:0.9182512164115906,VALIDATION ACCURACY:0.592199981212616
# Epoch 43, CIFAR-10 Batch 1:  LOSS:0.9861513376235962,VALIDATION ACCURACY:0.5888000130653381
# Epoch 43, CIFAR-10 Batch 2:  LOSS:0.9503577947616577,VALIDATION ACCURACY:0.5893999934196472
# Epoch 43, CIFAR-10 Batch 3:  LOSS:0.8586503863334656,VALIDATION ACCURACY:0.5974000096321106
# Epoch 43, CIFAR-10 Batch 4:  LOSS:0.8588269948959351,VALIDATION ACCURACY:0.5961999893188477
# Epoch 43, CIFAR-10 Batch 5:  LOSS:0.9298631548881531,VALIDATION ACCURACY:0.5843999981880188
# Epoch 44, CIFAR-10 Batch 1:  LOSS:0.9721498489379883,VALIDATION ACCURACY:0.5821999907493591
# Epoch 44, CIFAR-10 Batch 2:  LOSS:0.9548246264457703,VALIDATION ACCURACY:0.5834000110626221
# Epoch 44, CIFAR-10 Batch 3:  LOSS:0.8688414096832275,VALIDATION ACCURACY:0.5911999940872192
# Epoch 44, CIFAR-10 Batch 4:  LOSS:0.8686167597770691,VALIDATION ACCURACY:0.5989999771118164
# Epoch 44, CIFAR-10 Batch 5:  LOSS:0.9322231411933899,VALIDATION ACCURACY:0.5888000130653381
# Epoch 45, CIFAR-10 Batch 1:  LOSS:0.9530596137046814,VALIDATION ACCURACY:0.6011999845504761
# Epoch 45, CIFAR-10 Batch 2:  LOSS:0.9433424472808838,VALIDATION ACCURACY:0.5978000164031982
# Epoch 45, CIFAR-10 Batch 3:  LOSS:0.8149875998497009,VALIDATION ACCURACY:0.6065999865531921
# Epoch 45, CIFAR-10 Batch 4:  LOSS:0.8643195629119873,VALIDATION ACCURACY:0.6025999784469604
# Epoch 45, CIFAR-10 Batch 5:  LOSS:0.8882092833518982,VALIDATION ACCURACY:0.6003999710083008
# Epoch 46, CIFAR-10 Batch 1:  LOSS:0.9651921391487122,VALIDATION ACCURACY:0.5893999934196472
# Epoch 46, CIFAR-10 Batch 2:  LOSS:0.9148218035697937,VALIDATION ACCURACY:0.5974000096321106
# Epoch 46, CIFAR-10 Batch 3:  LOSS:0.8196926712989807,VALIDATION ACCURACY:0.6015999913215637
# Epoch 46, CIFAR-10 Batch 4:  LOSS:0.847247838973999,VALIDATION ACCURACY:0.6086000204086304
# Epoch 46, CIFAR-10 Batch 5:  LOSS:0.8748674392700195,VALIDATION ACCURACY:0.6010000109672546
# Epoch 47, CIFAR-10 Batch 1:  LOSS:0.9316859841346741,VALIDATION ACCURACY:0.6028000116348267
# Epoch 47, CIFAR-10 Batch 2:  LOSS:0.9309962391853333,VALIDATION ACCURACY:0.593999981880188
# Epoch 47, CIFAR-10 Batch 3:  LOSS:0.8245723843574524,VALIDATION ACCURACY:0.5953999757766724
# Epoch 47, CIFAR-10 Batch 4:  LOSS:0.8341870903968811,VALIDATION ACCURACY:0.6021999716758728
# Epoch 47, CIFAR-10 Batch 5:  LOSS:0.8581804633140564,VALIDATION ACCURACY:0.5989999771118164
# Epoch 48, CIFAR-10 Batch 1:  LOSS:0.9297223687171936,VALIDATION ACCURACY:0.6014000177383423
# Epoch 48, CIFAR-10 Batch 2:  LOSS:0.918265163898468,VALIDATION ACCURACY:0.5971999764442444
# Epoch 48, CIFAR-10 Batch 3:  LOSS:0.8268560171127319,VALIDATION ACCURACY:0.6079999804496765
# Epoch 48, CIFAR-10 Batch 4:  LOSS:0.8353154063224792,VALIDATION ACCURACY:0.603600025177002
# Epoch 48, CIFAR-10 Batch 5:  LOSS:0.8698664307594299,VALIDATION ACCURACY:0.6037999987602234
# Epoch 49, CIFAR-10 Batch 1:  LOSS:0.9331313371658325,VALIDATION ACCURACY:0.5953999757766724
# Epoch 49, CIFAR-10 Batch 2:  LOSS:0.9238107800483704,VALIDATION ACCURACY:0.5857999920845032
# Epoch 49, CIFAR-10 Batch 3:  LOSS:0.8374178409576416,VALIDATION ACCURACY:0.5920000076293945
# Epoch 49, CIFAR-10 Batch 4:  LOSS:0.8255835175514221,VALIDATION ACCURACY:0.6000000238418579
# Epoch 49, CIFAR-10 Batch 5:  LOSS:0.8664118647575378,VALIDATION ACCURACY:0.5960000157356262
# Epoch 50, CIFAR-10 Batch 1:  LOSS:0.9105626940727234,VALIDATION ACCURACY:0.6029999852180481
# Epoch 50, CIFAR-10 Batch 2:  LOSS:0.8921106457710266,VALIDATION ACCURACY:0.6047999858856201
# Epoch 50, CIFAR-10 Batch 3:  LOSS:0.815244197845459,VALIDATION ACCURACY:0.603600025177002
# Epoch 50, CIFAR-10 Batch 4:  LOSS:0.8222361207008362,VALIDATION ACCURACY:0.6104000210762024
# Epoch 50, CIFAR-10 Batch 5:  LOSS:0.8671534657478333,VALIDATION ACCURACY:0.6046000123023987
# Epoch 51, CIFAR-10 Batch 1:  LOSS:0.9194368720054626,VALIDATION ACCURACY:0.5979999899864197
# Epoch 51, CIFAR-10 Batch 2:  LOSS:0.9390683770179749,VALIDATION ACCURACY:0.5974000096321106
# Epoch 51, CIFAR-10 Batch 3:  LOSS:0.8183624744415283,VALIDATION ACCURACY:0.597000002861023
# Epoch 51, CIFAR-10 Batch 4:  LOSS:0.8185849189758301,VALIDATION ACCURACY:0.6075999736785889
# Epoch 51, CIFAR-10 Batch 5:  LOSS:0.8592013716697693,VALIDATION ACCURACY:0.6003999710083008
# Epoch 52, CIFAR-10 Batch 1:  LOSS:0.9241248369216919,VALIDATION ACCURACY:0.5902000069618225
# Epoch 52, CIFAR-10 Batch 2:  LOSS:0.9512796401977539,VALIDATION ACCURACY:0.6047999858856201
# Epoch 52, CIFAR-10 Batch 3:  LOSS:0.7871262431144714,VALIDATION ACCURACY:0.6046000123023987
# Epoch 52, CIFAR-10 Batch 4:  LOSS:0.8326257467269897,VALIDATION ACCURACY:0.5965999960899353
# Epoch 52, CIFAR-10 Batch 5:  LOSS:0.84001624584198,VALIDATION ACCURACY:0.6029999852180481
# Epoch 53, CIFAR-10 Batch 1:  LOSS:0.9187349081039429,VALIDATION ACCURACY:0.5979999899864197
# Epoch 53, CIFAR-10 Batch 2:  LOSS:0.9265390634536743,VALIDATION ACCURACY:0.605400025844574
# Epoch 53, CIFAR-10 Batch 3:  LOSS:0.7765232920646667,VALIDATION ACCURACY:0.6097999811172485
# Epoch 53, CIFAR-10 Batch 4:  LOSS:0.8268109560012817,VALIDATION ACCURACY:0.603600025177002
# Epoch 53, CIFAR-10 Batch 5:  LOSS:0.8301271200180054,VALIDATION ACCURACY:0.6032000184059143
# Epoch 54, CIFAR-10 Batch 1:  LOSS:0.902753472328186,VALIDATION ACCURACY:0.5979999899864197
# Epoch 54, CIFAR-10 Batch 2:  LOSS:0.9239774346351624,VALIDATION ACCURACY:0.5965999960899353
# Epoch 54, CIFAR-10 Batch 3:  LOSS:0.7737818360328674,VALIDATION ACCURACY:0.6078000068664551
# Epoch 54, CIFAR-10 Batch 4:  LOSS:0.8025518655776978,VALIDATION ACCURACY:0.6105999946594238
# Epoch 54, CIFAR-10 Batch 5:  LOSS:0.8226837515830994,VALIDATION ACCURACY:0.6057999730110168
# Epoch 55, CIFAR-10 Batch 1:  LOSS:0.8920449018478394,VALIDATION ACCURACY:0.5952000021934509
# Epoch 55, CIFAR-10 Batch 2:  LOSS:0.8861890435218811,VALIDATION ACCURACY:0.6078000068664551
# Epoch 55, CIFAR-10 Batch 3:  LOSS:0.7889550924301147,VALIDATION ACCURACY:0.605400025844574
# Epoch 55, CIFAR-10 Batch 4:  LOSS:0.7860425710678101,VALIDATION ACCURACY:0.6092000007629395
# Epoch 55, CIFAR-10 Batch 5:  LOSS:0.8153508901596069,VALIDATION ACCURACY:0.6097999811172485
# Epoch 56, CIFAR-10 Batch 1:  LOSS:0.8733880519866943,VALIDATION ACCURACY:0.6057999730110168
# Epoch 56, CIFAR-10 Batch 2:  LOSS:0.8939252495765686,VALIDATION ACCURACY:0.604200005531311
# Epoch 56, CIFAR-10 Batch 3:  LOSS:0.7712419629096985,VALIDATION ACCURACY:0.6093999743461609
# Epoch 56, CIFAR-10 Batch 4:  LOSS:0.7638667821884155,VALIDATION ACCURACY:0.6101999878883362
# Epoch 56, CIFAR-10 Batch 5:  LOSS:0.8181485533714294,VALIDATION ACCURACY:0.6019999980926514
# Epoch 57, CIFAR-10 Batch 1:  LOSS:0.8949941396713257,VALIDATION ACCURACY:0.6037999987602234
# Epoch 57, CIFAR-10 Batch 2:  LOSS:0.8988867998123169,VALIDATION ACCURACY:0.6083999872207642
# Epoch 57, CIFAR-10 Batch 3:  LOSS:0.752592146396637,VALIDATION ACCURACY:0.6118000149726868
# Epoch 57, CIFAR-10 Batch 4:  LOSS:0.7843626737594604,VALIDATION ACCURACY:0.600600004196167
# Epoch 57, CIFAR-10 Batch 5:  LOSS:0.7993934154510498,VALIDATION ACCURACY:0.6092000007629395
# Epoch 58, CIFAR-10 Batch 1:  LOSS:0.9083672761917114,VALIDATION ACCURACY:0.5892000198364258
# Epoch 58, CIFAR-10 Batch 2:  LOSS:0.9036003351211548,VALIDATION ACCURACY:0.6011999845504761
# Epoch 58, CIFAR-10 Batch 3:  LOSS:0.7549922466278076,VALIDATION ACCURACY:0.6114000082015991
# Epoch 58, CIFAR-10 Batch 4:  LOSS:0.7781105637550354,VALIDATION ACCURACY:0.6078000068664551
# Epoch 58, CIFAR-10 Batch 5:  LOSS:0.8160881996154785,VALIDATION ACCURACY:0.6093999743461609
# Epoch 59, CIFAR-10 Batch 1:  LOSS:0.8841285705566406,VALIDATION ACCURACY:0.6025999784469604
# Epoch 59, CIFAR-10 Batch 2:  LOSS:0.8709390759468079,VALIDATION ACCURACY:0.61080002784729
# Epoch 59, CIFAR-10 Batch 3:  LOSS:0.7650920748710632,VALIDATION ACCURACY:0.6105999946594238
# Epoch 59, CIFAR-10 Batch 4:  LOSS:0.7705480456352234,VALIDATION ACCURACY:0.6078000068664551
# Epoch 59, CIFAR-10 Batch 5:  LOSS:0.8110589385032654,VALIDATION ACCURACY:0.6114000082015991
# Epoch 60, CIFAR-10 Batch 1:  LOSS:0.8624975085258484,VALIDATION ACCURACY:0.6168000102043152
# Epoch 60, CIFAR-10 Batch 2:  LOSS:0.8316000699996948,VALIDATION ACCURACY:0.6168000102043152
# Epoch 60, CIFAR-10 Batch 3:  LOSS:0.7790921330451965,VALIDATION ACCURACY:0.6055999994277954
# Epoch 60, CIFAR-10 Batch 4:  LOSS:0.7858408093452454,VALIDATION ACCURACY:0.604200005531311
# Epoch 60, CIFAR-10 Batch 5:  LOSS:0.8297969102859497,VALIDATION ACCURACY:0.6075999736785889
# Epoch 61, CIFAR-10 Batch 1:  LOSS:0.8679231405258179,VALIDATION ACCURACY:0.6057999730110168
# Epoch 61, CIFAR-10 Batch 2:  LOSS:0.8363245129585266,VALIDATION ACCURACY:0.6173999905586243
# Epoch 61, CIFAR-10 Batch 3:  LOSS:0.7496156692504883,VALIDATION ACCURACY:0.6128000020980835
# Epoch 61, CIFAR-10 Batch 4:  LOSS:0.7629472613334656,VALIDATION ACCURACY:0.609000027179718
# Epoch 61, CIFAR-10 Batch 5:  LOSS:0.7974294424057007,VALIDATION ACCURACY:0.6114000082015991
# Epoch 62, CIFAR-10 Batch 1:  LOSS:0.8616232872009277,VALIDATION ACCURACY:0.6092000007629395
# Epoch 62, CIFAR-10 Batch 2:  LOSS:0.8308799266815186,VALIDATION ACCURACY:0.6236000061035156
# Epoch 62, CIFAR-10 Batch 3:  LOSS:0.7480235695838928,VALIDATION ACCURACY:0.6186000108718872
# Epoch 62, CIFAR-10 Batch 4:  LOSS:0.7562254667282104,VALIDATION ACCURACY:0.6114000082015991
# Epoch 62, CIFAR-10 Batch 5:  LOSS:0.7938494086265564,VALIDATION ACCURACY:0.6126000285148621
# Epoch 63, CIFAR-10 Batch 1:  LOSS:0.8633007407188416,VALIDATION ACCURACY:0.6105999946594238
# Epoch 63, CIFAR-10 Batch 2:  LOSS:0.8664994239807129,VALIDATION ACCURACY:0.6050000190734863
# Epoch 63, CIFAR-10 Batch 3:  LOSS:0.7364717125892639,VALIDATION ACCURACY:0.6141999959945679
# Epoch 63, CIFAR-10 Batch 4:  LOSS:0.7550451159477234,VALIDATION ACCURACY:0.6075999736785889
# Epoch 63, CIFAR-10 Batch 5:  LOSS:0.8571804761886597,VALIDATION ACCURACY:0.5888000130653381
# Epoch 64, CIFAR-10 Batch 1:  LOSS:0.8424816727638245,VALIDATION ACCURACY:0.6060000061988831
# Epoch 64, CIFAR-10 Batch 2:  LOSS:0.8603805303573608,VALIDATION ACCURACY:0.6055999994277954
# Epoch 64, CIFAR-10 Batch 3:  LOSS:0.7213556170463562,VALIDATION ACCURACY:0.6154000163078308
# Epoch 64, CIFAR-10 Batch 4:  LOSS:0.7331002354621887,VALIDATION ACCURACY:0.6114000082015991
# Epoch 64, CIFAR-10 Batch 5:  LOSS:0.8033514022827148,VALIDATION ACCURACY:0.6118000149726868
# Epoch 65, CIFAR-10 Batch 1:  LOSS:0.815970242023468,VALIDATION ACCURACY:0.6154000163078308
# Epoch 65, CIFAR-10 Batch 2:  LOSS:0.8345884084701538,VALIDATION ACCURACY:0.6194000244140625
# Epoch 65, CIFAR-10 Batch 3:  LOSS:0.7120357155799866,VALIDATION ACCURACY:0.6186000108718872
# Epoch 65, CIFAR-10 Batch 4:  LOSS:0.7201518416404724,VALIDATION ACCURACY:0.6195999979972839
# Epoch 65, CIFAR-10 Batch 5:  LOSS:0.7983938455581665,VALIDATION ACCURACY:0.6096000075340271
# Epoch 66, CIFAR-10 Batch 1:  LOSS:0.8447684049606323,VALIDATION ACCURACY:0.6104000210762024
# Epoch 66, CIFAR-10 Batch 2:  LOSS:0.8180286884307861,VALIDATION ACCURACY:0.6110000014305115
# Epoch 66, CIFAR-10 Batch 3:  LOSS:0.7179896235466003,VALIDATION ACCURACY:0.6169999837875366
# Epoch 66, CIFAR-10 Batch 4:  LOSS:0.748051106929779,VALIDATION ACCURACY:0.6093999743461609
# Epoch 66, CIFAR-10 Batch 5:  LOSS:0.7751245498657227,VALIDATION ACCURACY:0.61080002784729
# Epoch 67, CIFAR-10 Batch 1:  LOSS:0.8370389342308044,VALIDATION ACCURACY:0.6119999885559082
# Epoch 67, CIFAR-10 Batch 2:  LOSS:0.8630925416946411,VALIDATION ACCURACY:0.6150000095367432
# Epoch 67, CIFAR-10 Batch 3:  LOSS:0.7084099650382996,VALIDATION ACCURACY:0.6197999715805054
# Epoch 67, CIFAR-10 Batch 4:  LOSS:0.7307333946228027,VALIDATION ACCURACY:0.6172000169754028
# Epoch 67, CIFAR-10 Batch 5:  LOSS:0.7560383081436157,VALIDATION ACCURACY:0.6155999898910522
# Epoch 68, CIFAR-10 Batch 1:  LOSS:0.8087973594665527,VALIDATION ACCURACY:0.6118000149726868
# Epoch 68, CIFAR-10 Batch 2:  LOSS:0.8082982897758484,VALIDATION ACCURACY:0.6154000163078308
# Epoch 68, CIFAR-10 Batch 3:  LOSS:0.7234644889831543,VALIDATION ACCURACY:0.6146000027656555
# Epoch 68, CIFAR-10 Batch 4:  LOSS:0.7077430486679077,VALIDATION ACCURACY:0.6176000237464905
# Epoch 68, CIFAR-10 Batch 5:  LOSS:0.7711825966835022,VALIDATION ACCURACY:0.6176000237464905
# Epoch 69, CIFAR-10 Batch 1:  LOSS:0.8165126442909241,VALIDATION ACCURACY:0.6141999959945679
# Epoch 69, CIFAR-10 Batch 2:  LOSS:0.7949087023735046,VALIDATION ACCURACY:0.6227999925613403
# Epoch 69, CIFAR-10 Batch 3:  LOSS:0.7087774276733398,VALIDATION ACCURACY:0.6144000291824341
# Epoch 69, CIFAR-10 Batch 4:  LOSS:0.7260931134223938,VALIDATION ACCURACY:0.6097999811172485
# Epoch 69, CIFAR-10 Batch 5:  LOSS:0.772426187992096,VALIDATION ACCURACY:0.6118000149726868
# Epoch 70, CIFAR-10 Batch 1:  LOSS:0.79158616065979,VALIDATION ACCURACY:0.6159999966621399
# Epoch 70, CIFAR-10 Batch 2:  LOSS:0.8059901595115662,VALIDATION ACCURACY:0.6204000115394592
# Epoch 70, CIFAR-10 Batch 3:  LOSS:0.7093403339385986,VALIDATION ACCURACY:0.6150000095367432
# Epoch 70, CIFAR-10 Batch 4:  LOSS:0.7016672492027283,VALIDATION ACCURACY:0.6190000176429749
# Epoch 70, CIFAR-10 Batch 5:  LOSS:0.7553008794784546,VALIDATION ACCURACY:0.6115999817848206
# Epoch 71, CIFAR-10 Batch 1:  LOSS:0.8086093068122864,VALIDATION ACCURACY:0.6083999872207642
# Epoch 71, CIFAR-10 Batch 2:  LOSS:0.7974402904510498,VALIDATION ACCURACY:0.6244000196456909
# Epoch 71, CIFAR-10 Batch 3:  LOSS:0.6946028470993042,VALIDATION ACCURACY:0.6137999892234802
# Epoch 71, CIFAR-10 Batch 4:  LOSS:0.7207307815551758,VALIDATION ACCURACY:0.6158000230789185
# Epoch 71, CIFAR-10 Batch 5:  LOSS:0.7729154229164124,VALIDATION ACCURACY:0.6194000244140625
# Epoch 72, CIFAR-10 Batch 1:  LOSS:0.7894388437271118,VALIDATION ACCURACY:0.6161999702453613
# Epoch 72, CIFAR-10 Batch 2:  LOSS:0.7962625622749329,VALIDATION ACCURACY:0.6194000244140625
# Epoch 72, CIFAR-10 Batch 3:  LOSS:0.720805287361145,VALIDATION ACCURACY:0.6215999722480774
# Epoch 72, CIFAR-10 Batch 4:  LOSS:0.7125612497329712,VALIDATION ACCURACY:0.6187999844551086
# Epoch 72, CIFAR-10 Batch 5:  LOSS:0.7524384260177612,VALIDATION ACCURACY:0.6146000027656555
# Epoch 73, CIFAR-10 Batch 1:  LOSS:0.7632745504379272,VALIDATION ACCURACY:0.6215999722480774
# Epoch 73, CIFAR-10 Batch 2:  LOSS:0.7860748767852783,VALIDATION ACCURACY:0.6146000027656555
# Epoch 73, CIFAR-10 Batch 3:  LOSS:0.6886138916015625,VALIDATION ACCURACY:0.6179999709129333
# Epoch 73, CIFAR-10 Batch 4:  LOSS:0.6852165460586548,VALIDATION ACCURACY:0.6227999925613403
# Epoch 73, CIFAR-10 Batch 5:  LOSS:0.7582952976226807,VALIDATION ACCURACY:0.6169999837875366
# Epoch 74, CIFAR-10 Batch 1:  LOSS:0.7830901145935059,VALIDATION ACCURACY:0.6194000244140625
# Epoch 74, CIFAR-10 Batch 2:  LOSS:0.7834244966506958,VALIDATION ACCURACY:0.6244000196456909
# Epoch 74, CIFAR-10 Batch 3:  LOSS:0.6880992650985718,VALIDATION ACCURACY:0.6182000041007996
# Epoch 74, CIFAR-10 Batch 4:  LOSS:0.6965691447257996,VALIDATION ACCURACY:0.6176000237464905
# Epoch 74, CIFAR-10 Batch 5:  LOSS:0.7496278285980225,VALIDATION ACCURACY:0.6191999912261963
# Epoch 75, CIFAR-10 Batch 1:  LOSS:0.792434573173523,VALIDATION ACCURACY:0.6179999709129333
# Epoch 75, CIFAR-10 Batch 2:  LOSS:0.7599262595176697,VALIDATION ACCURACY:0.621999979019165
# Epoch 75, CIFAR-10 Batch 3:  LOSS:0.6654537320137024,VALIDATION ACCURACY:0.623199999332428
# Epoch 75, CIFAR-10 Batch 4:  LOSS:0.6705872416496277,VALIDATION ACCURACY:0.6209999918937683
# Epoch 75, CIFAR-10 Batch 5:  LOSS:0.7729626893997192,VALIDATION ACCURACY:0.6173999905586243
# Epoch 76, CIFAR-10 Batch 1:  LOSS:0.7904505729675293,VALIDATION ACCURACY:0.6209999918937683
# Epoch 76, CIFAR-10 Batch 2:  LOSS:0.7764660120010376,VALIDATION ACCURACY:0.6114000082015991
# Epoch 76, CIFAR-10 Batch 3:  LOSS:0.6968483328819275,VALIDATION ACCURACY:0.6208000183105469
# Epoch 76, CIFAR-10 Batch 4:  LOSS:0.6740874648094177,VALIDATION ACCURACY:0.6251999735832214
# Epoch 76, CIFAR-10 Batch 5:  LOSS:0.7426876425743103,VALIDATION ACCURACY:0.6168000102043152
# Epoch 77, CIFAR-10 Batch 1:  LOSS:0.7686534523963928,VALIDATION ACCURACY:0.6194000244140625
# Epoch 77, CIFAR-10 Batch 2:  LOSS:0.7516729831695557,VALIDATION ACCURACY:0.6172000169754028
# Epoch 77, CIFAR-10 Batch 3:  LOSS:0.6560012102127075,VALIDATION ACCURACY:0.6212000250816345
# Epoch 77, CIFAR-10 Batch 4:  LOSS:0.6768240928649902,VALIDATION ACCURACY:0.6194000244140625
# Epoch 77, CIFAR-10 Batch 5:  LOSS:0.7491573095321655,VALIDATION ACCURACY:0.6194000244140625
# Epoch 78, CIFAR-10 Batch 1:  LOSS:0.753607988357544,VALIDATION ACCURACY:0.6240000128746033
# Epoch 78, CIFAR-10 Batch 2:  LOSS:0.7612667083740234,VALIDATION ACCURACY:0.6176000237464905
# Epoch 78, CIFAR-10 Batch 3:  LOSS:0.686991274356842,VALIDATION ACCURACY:0.6177999973297119
# Epoch 78, CIFAR-10 Batch 4:  LOSS:0.672278642654419,VALIDATION ACCURACY:0.6244000196456909
# Epoch 78, CIFAR-10 Batch 5:  LOSS:0.7160202860832214,VALIDATION ACCURACY:0.6251999735832214
# Epoch 79, CIFAR-10 Batch 1:  LOSS:0.7358846664428711,VALIDATION ACCURACY:0.6269999742507935
# Epoch 79, CIFAR-10 Batch 2:  LOSS:0.7705060839653015,VALIDATION ACCURACY:0.6195999979972839
# Epoch 79, CIFAR-10 Batch 3:  LOSS:0.6647977232933044,VALIDATION ACCURACY:0.6136000156402588
# Epoch 79, CIFAR-10 Batch 4:  LOSS:0.6527041792869568,VALIDATION ACCURACY:0.6241999864578247
# Epoch 79, CIFAR-10 Batch 5:  LOSS:0.7141371965408325,VALIDATION ACCURACY:0.6179999709129333
# Epoch 80, CIFAR-10 Batch 1:  LOSS:0.7467429637908936,VALIDATION ACCURACY:0.6312000155448914
# Epoch 80, CIFAR-10 Batch 2:  LOSS:0.7635655999183655,VALIDATION ACCURACY:0.621399998664856
# Epoch 80, CIFAR-10 Batch 3:  LOSS:0.6759782433509827,VALIDATION ACCURACY:0.6182000041007996
# Epoch 80, CIFAR-10 Batch 4:  LOSS:0.6462766528129578,VALIDATION ACCURACY:0.631600022315979
# Epoch 80, CIFAR-10 Batch 5:  LOSS:0.726252555847168,VALIDATION ACCURACY:0.6222000122070312
# Epoch 81, CIFAR-10 Batch 1:  LOSS:0.7473713755607605,VALIDATION ACCURACY:0.6197999715805054
# Epoch 81, CIFAR-10 Batch 2:  LOSS:0.7372016906738281,VALIDATION ACCURACY:0.628000020980835
# Epoch 81, CIFAR-10 Batch 3:  LOSS:0.6658816337585449,VALIDATION ACCURACY:0.6230000257492065
# Epoch 81, CIFAR-10 Batch 4:  LOSS:0.654195249080658,VALIDATION ACCURACY:0.621399998664856
# Epoch 81, CIFAR-10 Batch 5:  LOSS:0.7466527223587036,VALIDATION ACCURACY:0.6118000149726868
# Epoch 82, CIFAR-10 Batch 1:  LOSS:0.7609899640083313,VALIDATION ACCURACY:0.6245999932289124
# Epoch 82, CIFAR-10 Batch 2:  LOSS:0.7668664455413818,VALIDATION ACCURACY:0.6159999966621399
# Epoch 82, CIFAR-10 Batch 3:  LOSS:0.6489013433456421,VALIDATION ACCURACY:0.6168000102043152
# Epoch 82, CIFAR-10 Batch 4:  LOSS:0.6510050296783447,VALIDATION ACCURACY:0.6281999945640564
# Epoch 82, CIFAR-10 Batch 5:  LOSS:0.7046703696250916,VALIDATION ACCURACY:0.6241999864578247
# Epoch 83, CIFAR-10 Batch 1:  LOSS:0.7351570129394531,VALIDATION ACCURACY:0.6240000128746033
# Epoch 83, CIFAR-10 Batch 2:  LOSS:0.7597562670707703,VALIDATION ACCURACY:0.6111999750137329
# Epoch 83, CIFAR-10 Batch 3:  LOSS:0.6622480154037476,VALIDATION ACCURACY:0.6195999979972839
# Epoch 83, CIFAR-10 Batch 4:  LOSS:0.6629931330680847,VALIDATION ACCURACY:0.6179999709129333
# Epoch 83, CIFAR-10 Batch 5:  LOSS:0.7181538939476013,VALIDATION ACCURACY:0.6262000203132629
# Epoch 84, CIFAR-10 Batch 1:  LOSS:0.7475854754447937,VALIDATION ACCURACY:0.6248000264167786
# Epoch 84, CIFAR-10 Batch 2:  LOSS:0.728631317615509,VALIDATION ACCURACY:0.621399998664856
# Epoch 84, CIFAR-10 Batch 3:  LOSS:0.6589207053184509,VALIDATION ACCURACY:0.6208000183105469
# Epoch 84, CIFAR-10 Batch 4:  LOSS:0.659083366394043,VALIDATION ACCURACY:0.6176000237464905
# Epoch 84, CIFAR-10 Batch 5:  LOSS:0.7092093229293823,VALIDATION ACCURACY:0.6226000189781189
# Epoch 85, CIFAR-10 Batch 1:  LOSS:0.7453513145446777,VALIDATION ACCURACY:0.6277999877929688
# Epoch 85, CIFAR-10 Batch 2:  LOSS:0.708838164806366,VALIDATION ACCURACY:0.6204000115394592
# Epoch 85, CIFAR-10 Batch 3:  LOSS:0.6310243010520935,VALIDATION ACCURACY:0.6191999912261963
# Epoch 85, CIFAR-10 Batch 4:  LOSS:0.6848241090774536,VALIDATION ACCURACY:0.6126000285148621
# Epoch 85, CIFAR-10 Batch 5:  LOSS:0.7305106520652771,VALIDATION ACCURACY:0.6245999932289124
# Epoch 86, CIFAR-10 Batch 1:  LOSS:0.7346128225326538,VALIDATION ACCURACY:0.6222000122070312
# Epoch 86, CIFAR-10 Batch 2:  LOSS:0.7279981374740601,VALIDATION ACCURACY:0.6237999796867371
# Epoch 86, CIFAR-10 Batch 3:  LOSS:0.6216368675231934,VALIDATION ACCURACY:0.628000020980835
# Epoch 86, CIFAR-10 Batch 4:  LOSS:0.6807534694671631,VALIDATION ACCURACY:0.6204000115394592
# Epoch 86, CIFAR-10 Batch 5:  LOSS:0.6925427317619324,VALIDATION ACCURACY:0.6263999938964844
# Epoch 87, CIFAR-10 Batch 1:  LOSS:0.7567996382713318,VALIDATION ACCURACY:0.6046000123023987
# Epoch 87, CIFAR-10 Batch 2:  LOSS:0.7682741284370422,VALIDATION ACCURACY:0.6205999851226807
# Epoch 87, CIFAR-10 Batch 3:  LOSS:0.6304485201835632,VALIDATION ACCURACY:0.6209999918937683
# Epoch 87, CIFAR-10 Batch 4:  LOSS:0.6311562061309814,VALIDATION ACCURACY:0.6294000148773193
# Epoch 87, CIFAR-10 Batch 5:  LOSS:0.6888287663459778,VALIDATION ACCURACY:0.621399998664856
# Epoch 88, CIFAR-10 Batch 1:  LOSS:0.7259452939033508,VALIDATION ACCURACY:0.6218000054359436
# Epoch 88, CIFAR-10 Batch 2:  LOSS:0.7389535903930664,VALIDATION ACCURACY:0.6236000061035156
# Epoch 88, CIFAR-10 Batch 3:  LOSS:0.6233811378479004,VALIDATION ACCURACY:0.6204000115394592
# Epoch 88, CIFAR-10 Batch 4:  LOSS:0.6434544920921326,VALIDATION ACCURACY:0.6137999892234802
# Epoch 88, CIFAR-10 Batch 5:  LOSS:0.6966801285743713,VALIDATION ACCURACY:0.6281999945640564
# Epoch 89, CIFAR-10 Batch 1:  LOSS:0.7298361659049988,VALIDATION ACCURACY:0.6161999702453613
# Epoch 89, CIFAR-10 Batch 2:  LOSS:0.7262819409370422,VALIDATION ACCURACY:0.629800021648407
# Epoch 89, CIFAR-10 Batch 3:  LOSS:0.6386129260063171,VALIDATION ACCURACY:0.6287999749183655
# Epoch 89, CIFAR-10 Batch 4:  LOSS:0.6126531362533569,VALIDATION ACCURACY:0.6244000196456909
# Epoch 89, CIFAR-10 Batch 5:  LOSS:0.6963521838188171,VALIDATION ACCURACY:0.6208000183105469
# Epoch 90, CIFAR-10 Batch 1:  LOSS:0.7384547591209412,VALIDATION ACCURACY:0.620199978351593
# Epoch 90, CIFAR-10 Batch 2:  LOSS:0.7436831593513489,VALIDATION ACCURACY:0.625
# Epoch 90, CIFAR-10 Batch 3:  LOSS:0.6559922695159912,VALIDATION ACCURACY:0.628000020980835
# Epoch 90, CIFAR-10 Batch 4:  LOSS:0.6383562088012695,VALIDATION ACCURACY:0.6262000203132629
# Epoch 90, CIFAR-10 Batch 5:  LOSS:0.6914750337600708,VALIDATION ACCURACY:0.6273999810218811
# Epoch 91, CIFAR-10 Batch 1:  LOSS:0.7044824361801147,VALIDATION ACCURACY:0.6281999945640564
# Epoch 91, CIFAR-10 Batch 2:  LOSS:0.7370122671127319,VALIDATION ACCURACY:0.6194000244140625
# Epoch 91, CIFAR-10 Batch 3:  LOSS:0.6234452724456787,VALIDATION ACCURACY:0.6263999938964844
# Epoch 91, CIFAR-10 Batch 4:  LOSS:0.6219486594200134,VALIDATION ACCURACY:0.629800021648407
# Epoch 91, CIFAR-10 Batch 5:  LOSS:0.7046782970428467,VALIDATION ACCURACY:0.6158000230789185
# Epoch 92, CIFAR-10 Batch 1:  LOSS:0.7150964736938477,VALIDATION ACCURACY:0.628600001335144
# Epoch 92, CIFAR-10 Batch 2:  LOSS:0.7093046307563782,VALIDATION ACCURACY:0.6226000189781189
# Epoch 92, CIFAR-10 Batch 3:  LOSS:0.6275844573974609,VALIDATION ACCURACY:0.6269999742507935
# Epoch 92, CIFAR-10 Batch 4:  LOSS:0.6209991574287415,VALIDATION ACCURACY:0.6287999749183655
# Epoch 92, CIFAR-10 Batch 5:  LOSS:0.6963749527931213,VALIDATION ACCURACY:0.6251999735832214
# Epoch 93, CIFAR-10 Batch 1:  LOSS:0.7312490344047546,VALIDATION ACCURACY:0.61080002784729
# Epoch 93, CIFAR-10 Batch 2:  LOSS:0.7152658700942993,VALIDATION ACCURACY:0.6259999871253967
# Epoch 93, CIFAR-10 Batch 3:  LOSS:0.6072366237640381,VALIDATION ACCURACY:0.6259999871253967
# Epoch 93, CIFAR-10 Batch 4:  LOSS:0.6255974769592285,VALIDATION ACCURACY:0.6276000142097473
# Epoch 93, CIFAR-10 Batch 5:  LOSS:0.6779516935348511,VALIDATION ACCURACY:0.6299999952316284
# Epoch 94, CIFAR-10 Batch 1:  LOSS:0.7245562672615051,VALIDATION ACCURACY:0.6151999831199646
# Epoch 94, CIFAR-10 Batch 2:  LOSS:0.6955900192260742,VALIDATION ACCURACY:0.6302000284194946
# Epoch 94, CIFAR-10 Batch 3:  LOSS:0.6154927015304565,VALIDATION ACCURACY:0.6272000074386597
# Epoch 94, CIFAR-10 Batch 4:  LOSS:0.6043264865875244,VALIDATION ACCURACY:0.633400022983551
# Epoch 94, CIFAR-10 Batch 5:  LOSS:0.6648799777030945,VALIDATION ACCURACY:0.6331999897956848
# Epoch 95, CIFAR-10 Batch 1:  LOSS:0.69053715467453,VALIDATION ACCURACY:0.6254000067710876
# Epoch 95, CIFAR-10 Batch 2:  LOSS:0.7352005243301392,VALIDATION ACCURACY:0.6227999925613403
# Epoch 95, CIFAR-10 Batch 3:  LOSS:0.6152859330177307,VALIDATION ACCURACY:0.6168000102043152
# Epoch 95, CIFAR-10 Batch 4:  LOSS:0.615808367729187,VALIDATION ACCURACY:0.6299999952316284
# Epoch 95, CIFAR-10 Batch 5:  LOSS:0.6620320677757263,VALIDATION ACCURACY:0.6295999884605408
# Epoch 96, CIFAR-10 Batch 1:  LOSS:0.691743791103363,VALIDATION ACCURACY:0.6305999755859375
# Epoch 96, CIFAR-10 Batch 2:  LOSS:0.7208895087242126,VALIDATION ACCURACY:0.623199999332428
# Epoch 96, CIFAR-10 Batch 3:  LOSS:0.6310844421386719,VALIDATION ACCURACY:0.6287999749183655
# Epoch 96, CIFAR-10 Batch 4:  LOSS:0.6157366633415222,VALIDATION ACCURACY:0.628600001335144
# Epoch 96, CIFAR-10 Batch 5:  LOSS:0.6748853921890259,VALIDATION ACCURACY:0.6222000122070312
# Epoch 97, CIFAR-10 Batch 1:  LOSS:0.7019935250282288,VALIDATION ACCURACY:0.6254000067710876
# Epoch 97, CIFAR-10 Batch 2:  LOSS:0.7483333349227905,VALIDATION ACCURACY:0.6197999715805054
# Epoch 97, CIFAR-10 Batch 3:  LOSS:0.6347215175628662,VALIDATION ACCURACY:0.6233999729156494
# Epoch 97, CIFAR-10 Batch 4:  LOSS:0.6260311007499695,VALIDATION ACCURACY:0.6251999735832214
# Epoch 97, CIFAR-10 Batch 5:  LOSS:0.6605337858200073,VALIDATION ACCURACY:0.6168000102043152
# Epoch 98, CIFAR-10 Batch 1:  LOSS:0.691051721572876,VALIDATION ACCURACY:0.6190000176429749
# Epoch 98, CIFAR-10 Batch 2:  LOSS:0.7095233798027039,VALIDATION ACCURACY:0.6222000122070312
# Epoch 98, CIFAR-10 Batch 3:  LOSS:0.6035755276679993,VALIDATION ACCURACY:0.6240000128746033
# Epoch 98, CIFAR-10 Batch 4:  LOSS:0.5929193496704102,VALIDATION ACCURACY:0.6277999877929688
# Epoch 98, CIFAR-10 Batch 5:  LOSS:0.663084089756012,VALIDATION ACCURACY:0.6190000176429749
# Epoch 99, CIFAR-10 Batch 1:  LOSS:0.7020546197891235,VALIDATION ACCURACY:0.6290000081062317
# Epoch 99, CIFAR-10 Batch 2:  LOSS:0.7835144400596619,VALIDATION ACCURACY:0.6129999756813049
# Epoch 99, CIFAR-10 Batch 3:  LOSS:0.6145361065864563,VALIDATION ACCURACY:0.6244000196456909
# Epoch 99, CIFAR-10 Batch 4:  LOSS:0.6260381937026978,VALIDATION ACCURACY:0.6320000290870667
# Epoch 99, CIFAR-10 Batch 5:  LOSS:0.621189534664154,VALIDATION ACCURACY:0.6295999884605408
# Epoch 100, CIFAR-10 Batch 1:  LOSS:0.6756671071052551,VALIDATION ACCURACY:0.6284000277519226
# Epoch 100, CIFAR-10 Batch 2:  LOSS:0.7684313058853149,VALIDATION ACCURACY:0.6065999865531921
# Epoch 100, CIFAR-10 Batch 3:  LOSS:0.6056426167488098,VALIDATION ACCURACY:0.6244000196456909
# Epoch 100, CIFAR-10 Batch 4:  LOSS:0.6230078935623169,VALIDATION ACCURACY:0.6254000067710876
# Epoch 100, CIFAR-10 Batch 5:  LOSS:0.6474001407623291,VALIDATION ACCURACY:0.6244000196456909
# Epoch 101, CIFAR-10 Batch 1:  LOSS:0.6884279251098633,VALIDATION ACCURACY:0.6254000067710876
# Epoch 101, CIFAR-10 Batch 2:  LOSS:0.7054879665374756,VALIDATION ACCURACY:0.628600001335144
# Epoch 101, CIFAR-10 Batch 3:  LOSS:0.5947058200836182,VALIDATION ACCURACY:0.6269999742507935
# Epoch 101, CIFAR-10 Batch 4:  LOSS:0.5838583111763,VALIDATION ACCURACY:0.628000020980835
# Epoch 101, CIFAR-10 Batch 5:  LOSS:0.6274973154067993,VALIDATION ACCURACY:0.6323999762535095
# Epoch 102, CIFAR-10 Batch 1:  LOSS:0.6901557445526123,VALIDATION ACCURACY:0.6233999729156494
# Epoch 102, CIFAR-10 Batch 2:  LOSS:0.7236910462379456,VALIDATION ACCURACY:0.616599977016449
# Epoch 102, CIFAR-10 Batch 3:  LOSS:0.5953999161720276,VALIDATION ACCURACY:0.6248000264167786
# Epoch 102, CIFAR-10 Batch 4:  LOSS:0.595454216003418,VALIDATION ACCURACY:0.6290000081062317
# Epoch 102, CIFAR-10 Batch 5:  LOSS:0.6299863457679749,VALIDATION ACCURACY:0.6305999755859375
# Epoch 103, CIFAR-10 Batch 1:  LOSS:0.6786684393882751,VALIDATION ACCURACY:0.6255999803543091
# Epoch 103, CIFAR-10 Batch 2:  LOSS:0.7182255983352661,VALIDATION ACCURACY:0.6129999756813049
# Epoch 103, CIFAR-10 Batch 3:  LOSS:0.6158341765403748,VALIDATION ACCURACY:0.6290000081062317
# Epoch 103, CIFAR-10 Batch 4:  LOSS:0.5839536190032959,VALIDATION ACCURACY:0.628000020980835
# Epoch 103, CIFAR-10 Batch 5:  LOSS:0.638288140296936,VALIDATION ACCURACY:0.635200023651123
# Epoch 104, CIFAR-10 Batch 1:  LOSS:0.6779991388320923,VALIDATION ACCURACY:0.6273999810218811
# Epoch 104, CIFAR-10 Batch 2:  LOSS:0.7065097093582153,VALIDATION ACCURACY:0.6258000135421753
# Epoch 104, CIFAR-10 Batch 3:  LOSS:0.5864992141723633,VALIDATION ACCURACY:0.6308000087738037
# Epoch 104, CIFAR-10 Batch 4:  LOSS:0.6031373739242554,VALIDATION ACCURACY:0.6248000264167786
# Epoch 104, CIFAR-10 Batch 5:  LOSS:0.6239317655563354,VALIDATION ACCURACY:0.6353999972343445
# Epoch 105, CIFAR-10 Batch 1:  LOSS:0.6810010671615601,VALIDATION ACCURACY:0.6313999891281128
# Epoch 105, CIFAR-10 Batch 2:  LOSS:0.7369623184204102,VALIDATION ACCURACY:0.604200005531311
# Epoch 105, CIFAR-10 Batch 3:  LOSS:0.5692518949508667,VALIDATION ACCURACY:0.6269999742507935
# Epoch 105, CIFAR-10 Batch 4:  LOSS:0.5829401016235352,VALIDATION ACCURACY:0.6330000162124634
# Epoch 105, CIFAR-10 Batch 5:  LOSS:0.6384137868881226,VALIDATION ACCURACY:0.6215999722480774
# Epoch 106, CIFAR-10 Batch 1:  LOSS:0.6700429916381836,VALIDATION ACCURACY:0.6322000026702881
# Epoch 106, CIFAR-10 Batch 2:  LOSS:0.6672660112380981,VALIDATION ACCURACY:0.6245999932289124
# Epoch 106, CIFAR-10 Batch 3:  LOSS:0.6051974892616272,VALIDATION ACCURACY:0.6236000061035156
# Epoch 106, CIFAR-10 Batch 4:  LOSS:0.5810721516609192,VALIDATION ACCURACY:0.6341999769210815
# Epoch 106, CIFAR-10 Batch 5:  LOSS:0.6103565096855164,VALIDATION ACCURACY:0.6294000148773193
# Epoch 107, CIFAR-10 Batch 1:  LOSS:0.6747778654098511,VALIDATION ACCURACY:0.6273999810218811
# Epoch 107, CIFAR-10 Batch 2:  LOSS:0.6699528098106384,VALIDATION ACCURACY:0.626800000667572
# Epoch 107, CIFAR-10 Batch 3:  LOSS:0.5922433137893677,VALIDATION ACCURACY:0.6320000290870667
# Epoch 107, CIFAR-10 Batch 4:  LOSS:0.5839357376098633,VALIDATION ACCURACY:0.6309999823570251
# Epoch 107, CIFAR-10 Batch 5:  LOSS:0.6263567805290222,VALIDATION ACCURACY:0.6290000081062317
# Epoch 108, CIFAR-10 Batch 1:  LOSS:0.6684326529502869,VALIDATION ACCURACY:0.6327999830245972
# Epoch 108, CIFAR-10 Batch 2:  LOSS:0.6990336775779724,VALIDATION ACCURACY:0.6277999877929688
# Epoch 108, CIFAR-10 Batch 3:  LOSS:0.5709625482559204,VALIDATION ACCURACY:0.628600001335144
# Epoch 108, CIFAR-10 Batch 4:  LOSS:0.590936005115509,VALIDATION ACCURACY:0.6263999938964844
# Epoch 108, CIFAR-10 Batch 5:  LOSS:0.6180203557014465,VALIDATION ACCURACY:0.6317999958992004
# Epoch 109, CIFAR-10 Batch 1:  LOSS:0.6699919700622559,VALIDATION ACCURACY:0.6281999945640564
# Epoch 109, CIFAR-10 Batch 2:  LOSS:0.7120177745819092,VALIDATION ACCURACY:0.6129999756813049
# Epoch 109, CIFAR-10 Batch 3:  LOSS:0.6027085185050964,VALIDATION ACCURACY:0.6237999796867371
# Epoch 109, CIFAR-10 Batch 4:  LOSS:0.5743454694747925,VALIDATION ACCURACY:0.6313999891281128
# Epoch 109, CIFAR-10 Batch 5:  LOSS:0.6281225085258484,VALIDATION ACCURACY:0.6195999979972839
# Epoch 110, CIFAR-10 Batch 1:  LOSS:0.6522951722145081,VALIDATION ACCURACY:0.6358000040054321
# Epoch 110, CIFAR-10 Batch 2:  LOSS:0.6635583639144897,VALIDATION ACCURACY:0.6355999708175659
# Epoch 110, CIFAR-10 Batch 3:  LOSS:0.5760585069656372,VALIDATION ACCURACY:0.6302000284194946
# Epoch 110, CIFAR-10 Batch 4:  LOSS:0.5636684894561768,VALIDATION ACCURACY:0.6363999843597412
# Epoch 110, CIFAR-10 Batch 5:  LOSS:0.6300946474075317,VALIDATION ACCURACY:0.6287999749183655
# Epoch 111, CIFAR-10 Batch 1:  LOSS:0.6801851391792297,VALIDATION ACCURACY:0.628600001335144
# Epoch 111, CIFAR-10 Batch 2:  LOSS:0.6512877941131592,VALIDATION ACCURACY:0.6241999864578247
# Epoch 111, CIFAR-10 Batch 3:  LOSS:0.5682992935180664,VALIDATION ACCURACY:0.6230000257492065
# Epoch 111, CIFAR-10 Batch 4:  LOSS:0.5726444125175476,VALIDATION ACCURACY:0.626800000667572
# Epoch 111, CIFAR-10 Batch 5:  LOSS:0.6169165372848511,VALIDATION ACCURACY:0.6330000162124634
# Epoch 112, CIFAR-10 Batch 1:  LOSS:0.6733155250549316,VALIDATION ACCURACY:0.6291999816894531
# Epoch 112, CIFAR-10 Batch 2:  LOSS:0.6606832146644592,VALIDATION ACCURACY:0.6308000087738037
# Epoch 112, CIFAR-10 Batch 3:  LOSS:0.5651552677154541,VALIDATION ACCURACY:0.6359999775886536
# Epoch 112, CIFAR-10 Batch 4:  LOSS:0.5827560424804688,VALIDATION ACCURACY:0.629800021648407
# Epoch 112, CIFAR-10 Batch 5:  LOSS:0.608633279800415,VALIDATION ACCURACY:0.6266000270843506
# Epoch 113, CIFAR-10 Batch 1:  LOSS:0.6891871094703674,VALIDATION ACCURACY:0.6323999762535095
# Epoch 113, CIFAR-10 Batch 2:  LOSS:0.6804488301277161,VALIDATION ACCURACY:0.6299999952316284
# Epoch 113, CIFAR-10 Batch 3:  LOSS:0.5787755846977234,VALIDATION ACCURACY:0.6240000128746033
# Epoch 113, CIFAR-10 Batch 4:  LOSS:0.5572992563247681,VALIDATION ACCURACY:0.631600022315979
# Epoch 113, CIFAR-10 Batch 5:  LOSS:0.613985538482666,VALIDATION ACCURACY:0.6258000135421753
# Epoch 114, CIFAR-10 Batch 1:  LOSS:0.6606151461601257,VALIDATION ACCURACY:0.6358000040054321
# Epoch 114, CIFAR-10 Batch 2:  LOSS:0.6507627367973328,VALIDATION ACCURACY:0.6273999810218811
# Epoch 114, CIFAR-10 Batch 3:  LOSS:0.5790079236030579,VALIDATION ACCURACY:0.6251999735832214
# Epoch 114, CIFAR-10 Batch 4:  LOSS:0.5584726333618164,VALIDATION ACCURACY:0.6287999749183655
# Epoch 114, CIFAR-10 Batch 5:  LOSS:0.6109461784362793,VALIDATION ACCURACY:0.6299999952316284
# Epoch 115, CIFAR-10 Batch 1:  LOSS:0.6962528824806213,VALIDATION ACCURACY:0.6158000230789185
# Epoch 115, CIFAR-10 Batch 2:  LOSS:0.6546629667282104,VALIDATION ACCURACY:0.6255999803543091
# Epoch 115, CIFAR-10 Batch 3:  LOSS:0.5633067488670349,VALIDATION ACCURACY:0.6308000087738037
# Epoch 115, CIFAR-10 Batch 4:  LOSS:0.5603181719779968,VALIDATION ACCURACY:0.6272000074386597
# Epoch 115, CIFAR-10 Batch 5:  LOSS:0.6752473711967468,VALIDATION ACCURACY:0.6111999750137329
# Epoch 116, CIFAR-10 Batch 1:  LOSS:0.6695241332054138,VALIDATION ACCURACY:0.6371999979019165
# Epoch 116, CIFAR-10 Batch 2:  LOSS:0.6378323435783386,VALIDATION ACCURACY:0.6299999952316284
# Epoch 116, CIFAR-10 Batch 3:  LOSS:0.6079264879226685,VALIDATION ACCURACY:0.626800000667572
# Epoch 116, CIFAR-10 Batch 4:  LOSS:0.5686154961585999,VALIDATION ACCURACY:0.6269999742507935
# Epoch 116, CIFAR-10 Batch 5:  LOSS:0.6153199672698975,VALIDATION ACCURACY:0.6338000297546387
# Epoch 117, CIFAR-10 Batch 1:  LOSS:0.6844329237937927,VALIDATION ACCURACY:0.6272000074386597
# Epoch 117, CIFAR-10 Batch 2:  LOSS:0.63592928647995,VALIDATION ACCURACY:0.6294000148773193
# Epoch 117, CIFAR-10 Batch 3:  LOSS:0.5951669812202454,VALIDATION ACCURACY:0.6248000264167786
# Epoch 117, CIFAR-10 Batch 4:  LOSS:0.563027024269104,VALIDATION ACCURACY:0.6331999897956848
# Epoch 117, CIFAR-10 Batch 5:  LOSS:0.6526909470558167,VALIDATION ACCURACY:0.6241999864578247
# Epoch 118, CIFAR-10 Batch 1:  LOSS:0.6614853143692017,VALIDATION ACCURACY:0.6312000155448914
# Epoch 118, CIFAR-10 Batch 2:  LOSS:0.6446778774261475,VALIDATION ACCURACY:0.6294000148773193
# Epoch 118, CIFAR-10 Batch 3:  LOSS:0.5946004986763,VALIDATION ACCURACY:0.6276000142097473
# Epoch 118, CIFAR-10 Batch 4:  LOSS:0.5495444536209106,VALIDATION ACCURACY:0.6295999884605408
# Epoch 118, CIFAR-10 Batch 5:  LOSS:0.6608888506889343,VALIDATION ACCURACY:0.6154000163078308
# Epoch 119, CIFAR-10 Batch 1:  LOSS:0.6630616188049316,VALIDATION ACCURACY:0.6384000182151794
# Epoch 119, CIFAR-10 Batch 2:  LOSS:0.6257715225219727,VALIDATION ACCURACY:0.635200023651123
# Epoch 119, CIFAR-10 Batch 3:  LOSS:0.5684891939163208,VALIDATION ACCURACY:0.6322000026702881
# Epoch 119, CIFAR-10 Batch 4:  LOSS:0.5527853965759277,VALIDATION ACCURACY:0.631600022315979
# Epoch 119, CIFAR-10 Batch 5:  LOSS:0.6377785801887512,VALIDATION ACCURACY:0.6212000250816345
# Epoch 120, CIFAR-10 Batch 1:  LOSS:0.6771290898323059,VALIDATION ACCURACY:0.6302000284194946
# Epoch 120, CIFAR-10 Batch 2:  LOSS:0.6464496850967407,VALIDATION ACCURACY:0.631600022315979
# Epoch 120, CIFAR-10 Batch 3:  LOSS:0.5736764669418335,VALIDATION ACCURACY:0.6349999904632568
# Epoch 120, CIFAR-10 Batch 4:  LOSS:0.5554322004318237,VALIDATION ACCURACY:0.6398000121116638
# Epoch 120, CIFAR-10 Batch 5:  LOSS:0.601983368396759,VALIDATION ACCURACY:0.6294000148773193
# Epoch 121, CIFAR-10 Batch 1:  LOSS:0.6920437216758728,VALIDATION ACCURACY:0.6233999729156494
# Epoch 121, CIFAR-10 Batch 2:  LOSS:0.6466092467308044,VALIDATION ACCURACY:0.6435999870300293
# Epoch 121, CIFAR-10 Batch 3:  LOSS:0.5769328474998474,VALIDATION ACCURACY:0.6322000026702881
# Epoch 121, CIFAR-10 Batch 4:  LOSS:0.5453733801841736,VALIDATION ACCURACY:0.6335999965667725
# Epoch 121, CIFAR-10 Batch 5:  LOSS:0.6295503973960876,VALIDATION ACCURACY:0.6144000291824341
# Epoch 122, CIFAR-10 Batch 1:  LOSS:0.6522154211997986,VALIDATION ACCURACY:0.6230000257492065
# Epoch 122, CIFAR-10 Batch 2:  LOSS:0.6355045437812805,VALIDATION ACCURACY:0.6341999769210815
# Epoch 122, CIFAR-10 Batch 3:  LOSS:0.5458672642707825,VALIDATION ACCURACY:0.6323999762535095
# Epoch 122, CIFAR-10 Batch 4:  LOSS:0.5724775791168213,VALIDATION ACCURACY:0.6295999884605408
# Epoch 122, CIFAR-10 Batch 5:  LOSS:0.6180207133293152,VALIDATION ACCURACY:0.6208000183105469
# Epoch 123, CIFAR-10 Batch 1:  LOSS:0.6863160133361816,VALIDATION ACCURACY:0.631600022315979
# Epoch 123, CIFAR-10 Batch 2:  LOSS:0.6138409376144409,VALIDATION ACCURACY:0.6413999795913696
# Epoch 123, CIFAR-10 Batch 3:  LOSS:0.5865842700004578,VALIDATION ACCURACY:0.6290000081062317
# Epoch 123, CIFAR-10 Batch 4:  LOSS:0.5464191436767578,VALIDATION ACCURACY:0.6338000297546387
# Epoch 123, CIFAR-10 Batch 5:  LOSS:0.6377911567687988,VALIDATION ACCURACY:0.6132000088691711
# Epoch 124, CIFAR-10 Batch 1:  LOSS:0.6635831594467163,VALIDATION ACCURACY:0.6341999769210815
# Epoch 124, CIFAR-10 Batch 2:  LOSS:0.6065046787261963,VALIDATION ACCURACY:0.6362000107765198
# Epoch 124, CIFAR-10 Batch 3:  LOSS:0.5615564584732056,VALIDATION ACCURACY:0.6384000182151794
# Epoch 124, CIFAR-10 Batch 4:  LOSS:0.5322957634925842,VALIDATION ACCURACY:0.6389999985694885
# Epoch 124, CIFAR-10 Batch 5:  LOSS:0.6126722097396851,VALIDATION ACCURACY:0.6313999891281128
# Epoch 125, CIFAR-10 Batch 1:  LOSS:0.6677684187889099,VALIDATION ACCURACY:0.6330000162124634
# Epoch 125, CIFAR-10 Batch 2:  LOSS:0.6000574231147766,VALIDATION ACCURACY:0.6359999775886536
# Epoch 125, CIFAR-10 Batch 3:  LOSS:0.5654688477516174,VALIDATION ACCURACY:0.6254000067710876
# Epoch 125, CIFAR-10 Batch 4:  LOSS:0.548711895942688,VALIDATION ACCURACY:0.6322000026702881
# Epoch 125, CIFAR-10 Batch 5:  LOSS:0.5832338929176331,VALIDATION ACCURACY:0.6281999945640564
# Epoch 126, CIFAR-10 Batch 1:  LOSS:0.6785467863082886,VALIDATION ACCURACY:0.628600001335144
# Epoch 126, CIFAR-10 Batch 2:  LOSS:0.6037733554840088,VALIDATION ACCURACY:0.6424000263214111
# Epoch 126, CIFAR-10 Batch 3:  LOSS:0.5562330484390259,VALIDATION ACCURACY:0.6323999762535095
# Epoch 126, CIFAR-10 Batch 4:  LOSS:0.5370340347290039,VALIDATION ACCURACY:0.6326000094413757
# Epoch 126, CIFAR-10 Batch 5:  LOSS:0.5977899432182312,VALIDATION ACCURACY:0.6191999912261963
# Epoch 127, CIFAR-10 Batch 1:  LOSS:0.6694732904434204,VALIDATION ACCURACY:0.6353999972343445
# Epoch 127, CIFAR-10 Batch 2:  LOSS:0.616424024105072,VALIDATION ACCURACY:0.6385999917984009
# Epoch 127, CIFAR-10 Batch 3:  LOSS:0.5442165732383728,VALIDATION ACCURACY:0.633400022983551
# Epoch 127, CIFAR-10 Batch 4:  LOSS:0.5535860061645508,VALIDATION ACCURACY:0.6284000277519226
# Epoch 127, CIFAR-10 Batch 5:  LOSS:0.5927404165267944,VALIDATION ACCURACY:0.6359999775886536
# Epoch 128, CIFAR-10 Batch 1:  LOSS:0.6672640442848206,VALIDATION ACCURACY:0.6273999810218811
# Epoch 128, CIFAR-10 Batch 2:  LOSS:0.6093557476997375,VALIDATION ACCURACY:0.6290000081062317
# Epoch 128, CIFAR-10 Batch 3:  LOSS:0.5566458106040955,VALIDATION ACCURACY:0.6309999823570251
# Epoch 128, CIFAR-10 Batch 4:  LOSS:0.5641852617263794,VALIDATION ACCURACY:0.6355999708175659
# Epoch 128, CIFAR-10 Batch 5:  LOSS:0.6201601028442383,VALIDATION ACCURACY:0.6223999857902527

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6154354333877563

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
